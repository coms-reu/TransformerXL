# %% [markdown]
# ---
# # Transformer XL
# ---

# %% [markdown]
# ---
# # Import Libraries

# %%
import os
import sys

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# %%
sys.path.append("../../deep-learning-dna")

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display
import math
import string

import BigBird
import Set_Transformer 
from common.models import dnabert
from common import dna
from lmdbm import Lmdb
from common.data import DnaSequenceGenerator, DnaLabelType, DnaSampleGenerator, find_dbs
import wandb

import tf_utils as tfu

# %%
strategy = tfu.devices.select_gpu(1, use_dynamic_memory=True)

# %% [markdown]
# ---
# # Load Data

# %%
#Import pretrained model
api = wandb.Api()
model_path = api.artifact("sirdavidludwig/deep-learning-dna/dnabert-pretrain-ablation-dim:8dim").download()
pretrained_model = dnabert.DnaBertModel.load(model_path)
pretrained_model

# %%
#Load datafiles
dataset_path = api.artifact("sirdavidludwig/nachusa-dna/dnasamples:v1").download('/data/dna_samples:v1')
samples = find_dbs(dataset_path + '/train')
samples[13]
# Out:
# wandb: Downloading large artifact dnasamples:v1, 4086.55MB. 1260 files... Done. 0:0:0.3
# '/data/dna_samples:v1/train/WS-CCW-Jul2015_S82_L001_R1_001.db'

# %% [markdown]
# ---
# # Create Dataset

# %%
split_ratios = [0.8, 0.2]
set_len = 1000
sequence_len = 150
kmer = 3
batch_size = 20
batches_per_epoch = 20
augument = True
labels = DnaLabelType.SampleIds
seed = 0
rng = np.random.default_rng(seed)
random_samples = samples.copy()

# %%
rng.shuffle(random_samples)

# %%
trimmed_samples, (train_dataset, val_dataset) = DnaSampleGenerator.split(samples=random_samples[0:50], split_ratios=split_ratios, subsample_length=set_len, sequence_length=sequence_len,kmer=kmer,batch_size=batch_size,batches_per_epoch=batches_per_epoch,augment=augument,labels=labels, rng=rng)
# Out:
# Sample '/data/dna_samples:v1/train/Wes7-PCRblank1_S8_L001_R1_001.db' does not contain enough sequences. This sample will be ignored.
# Sample '/data/dna_samples:v1/train/Wes7-PCRblank1_S8_L001_R1_001.db' does not contain enough sequences. This sample will be ignored.

# %%
random_samples[0:50]
# Out:
# ['/data/dna_samples:v1/train/WS-CCE-Apr2016_S6_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes52-10-TC_S53_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-WH-Jul2016_S46_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes41-10-HN_S42_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley026-Ag-072820_S165_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-MU-Apr2016_S84_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes5-5-CCE_S6_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-MR-Apr2016_S13_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-MU-Sep2015_S43_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley012-HN-051120_S151_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-HPN-Sep2015_S91_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TCR-Sep2015_S52_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes26-8-AG_S27_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SB-Jul2016_S22_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes25-8-MU_S26_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SB-Oct2016_S63_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes3-5-TCR_S4_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-WH-May2015_S160_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TCR-Oct2016_S80_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TC-Jul2015_S74_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SB-Sep2015_S35_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-CCW-Sep2015_S28_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TC-Oct2016_S48_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-HF-Jul2015_S42_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TCR-May2015_S73_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-HPN-Apr2016_S37_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-AG-Apr2016_S85_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes7-PCRblank1_S8_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes20-8-HF_S21_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes38-10-WH_S39_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley047-SF-100420_S186_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley055-HAP-051120_S194_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley006-HLP-051220_S145_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes39-10-HF_S40_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SF-Jul2016_S38_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley035-HLP2-072820_S174_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes13-5-HLP_S14_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-HPN-May2015_S17_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley005-HF-051220_S144_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes47-10-FC_S48_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SF-May2015_S152_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley045-HLP-100420_S184_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley033-MU-072820_S172_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley043-L-100420_S182_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes48-10-CCW_S49_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-AG-Sep2015_S44_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley010-HW-051120_S149_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes36-8-HW_S37_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley011-Ag-051120_S150_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley027-HLP-072820_S166_L001_R1_001.db']

# %% [markdown]
# ---
# # Batch Parameters

# %%
block_size = 200
seq_len = set_len
maxlen = set_len
vocab_size = 5
num_chars_data = set_len*sequence_len
max_files = len(train_dataset.samples)
max_files
# Out:
# 49

# %%
if block_size-2 > seq_len:
    raise ValueError("Block size should not be bigger than sequence length")

# %%
print(maxlen)
print(vocab_size)
print(num_chars_data)
# Out:
# 1000
# 5
# 150000

# %% [markdown]
# ---
# # Create Embeddings

# %%
#Create 8 dimensional embeddings
pretrained_encoder = dnabert.DnaBertEncoderModel(pretrained_model.base)
pretrained_encoder.trainable = False

# %%
class Create_Embeddings(keras.layers.Layer):
    def __init__(self, encoder):
        super(Create_Embeddings, self).__init__()
        self.encoder = encoder
        
    def subbatch_predict(self, model, batch, subbatch_size, concat=lambda old, new: tf.concat((old, new), axis=0)):
        def predict(i, result=None):
            n = i + subbatch_size
            pred = tf.stop_gradient(model(batch[i:n]))
            if result is None:
                return [n, pred]
            return [n, concat(result, pred)]
        i, result = predict(0)
        batch_size = tf.shape(batch)[0]
        i, result = tf.while_loop(
            cond=lambda i, _: i < batch_size,
            body=predict,
            loop_vars=[i, result],
            parallel_iterations=1)

        return result
    
    def modify_data_for_input(self, data):
        batch_size = tf.shape(data)[0]
        subsample_size = tf.shape(data)[1]
        flat_data = tf.reshape(data, (batch_size*subsample_size, -1))
        encoded = self.subbatch_predict(self.encoder, flat_data, 128)
        return tf.reshape(encoded, (batch_size, subsample_size, -1))
    
    def call(self, data):
        return  self.modify_data_for_input(data)

# %% [markdown]
# ---
# # Setup

# %%
def clone_initializer(initializer):
    if isinstance(initializer, tf.keras.initializers.Initializer):
        return initializer.__class__.from_config(initializer.get_config())
    return initializer

# %%
mask = tf.ones(tf.shape(train_dataset[0][0])[:-1])

# %% [markdown]
# ---
# # Create Big Bird Masks

# %%
class Create_BigBird_Masks(keras.layers.Layer):
    def __init__(self, attention_block_size):
        super(Create_BigBird_Masks, self).__init__()
            
        self.mask_layer = BigBird.BigBirdMasks(block_size=attention_block_size)
        
    def call(self, one_batch):

        mask = tf.ones(tf.shape(one_batch)[:-1])
                       
        masks = self.mask_layer(one_batch, mask)      
        
        return masks

# %% [markdown]
# ---
# # Cache Memory

# %%
def _cache_memory(current_state, previous_state, memory_length, reuse_length=0):
    if memory_length is None or memory_length == 0:
        return None
    else:
        if reuse_length > 0:
            current_state = current_state[:, :reuse_length, :]

        if previous_state is None:
            new_mem = current_state[:, -memory_length:, :]
        else:
            new_mem = tf.concat(
                    [previous_state, current_state], 1)[:, -memory_length:, :]

    return tf.stop_gradient(new_mem)

# %% [markdown]
# ---
# # XL Block

# %%
class TransformerXLBlock(tf.keras.layers.Layer):
    def __init__(self,
                 vocab_size,
                 hidden_size,
                 num_attention_heads,
                 head_size,
                 inner_size,
                 dropout_rate,
                 attention_dropout_rate,
                 norm_epsilon=1e-12,
                 inner_activation="relu",
                 kernel_initializer="variance_scaling",
                 inner_dropout=0.0,
                 **kwargs):

        super(TransformerXLBlock, self).__init__(**kwargs)
        self._vocab_size = vocab_size
        self._num_heads = num_attention_heads
        self._head_size = head_size
        self._hidden_size = hidden_size
        self._inner_size = inner_size
        self._dropout_rate = dropout_rate
        self._attention_dropout_rate = attention_dropout_rate
        self._inner_activation = inner_activation
        self._norm_epsilon = norm_epsilon
        self._kernel_initializer = kernel_initializer
        self._inner_dropout = inner_dropout
        self._attention_layer_type = BigBird.BigBirdAttention
        
    def build(self, input_shape):
        input_tensor = input_shape[0] if len(input_shape) == 2 else input_shape
        input_tensor_shape = tf.TensorShape(input_tensor)
        if len(input_tensor_shape.as_list()) != 3:
            raise ValueError("TransformerLayer expects a three-dimensional input of "
                                             "shape [batch, sequence, width].")
        batch_size, sequence_length, hidden_size = input_tensor_shape

        if len(input_shape) == 2:
            mask_tensor_shape = tf.TensorShape(input_shape[1])
            expected_mask_tensor_shape = tf.TensorShape(
                    [batch_size, sequence_length, sequence_length])
            if not expected_mask_tensor_shape.is_compatible_with(mask_tensor_shape):
                raise ValueError("When passing a mask tensor to TransformerXLBlock, "
                                                 "the mask tensor must be of shape [batch, "
                                                 "sequence_length, sequence_length] (here %s). Got a "
                                                 "mask tensor of shape %s." %
                                                 (expected_mask_tensor_shape, mask_tensor_shape))
        if hidden_size % self._num_heads != 0:
            raise ValueError(
                    "The input size (%d) is not a multiple of the number of attention "
                    "heads (%d)" % (hidden_size, self._num_heads))
            

        self._attention_layer = self._attention_layer_type(num_heads=8,key_dim=32, num_rand_blocks=8,from_block_size=8,to_block_size=8,max_rand_mask_length=set_len)
        
        self._attention_dropout = tf.keras.layers.Dropout(
                rate=self._attention_dropout_rate)
        self._attention_layer_norm = tf.keras.layers.LayerNormalization(
                name="self_attention_layer_norm",
                axis=-1,
                epsilon=self._norm_epsilon,
                dtype=tf.float32)
        self._inner_dense = tf.keras.layers.experimental.EinsumDense(
                "abc,cd->abd",
                output_shape=(None, self._inner_size),
                bias_axes="d",
                kernel_initializer=clone_initializer(self._kernel_initializer),
                name="inner")

        self._inner_activation_layer = tf.keras.layers.Activation(
                self._inner_activation)
        self._inner_dropout_layer = tf.keras.layers.Dropout(
                rate=self._inner_dropout)
        self._output_dense = tf.keras.layers.experimental.EinsumDense(
                "abc,cd->abd",
                output_shape=(None, hidden_size),
                bias_axes="d",
                name="output",
                kernel_initializer=clone_initializer(self._kernel_initializer))
        self._output_dropout = tf.keras.layers.Dropout(rate=self._dropout_rate)
        self._output_layer_norm = tf.keras.layers.LayerNormalization(
                name="output_layer_norm",
                axis=-1,
                epsilon=self._norm_epsilon)

        super(TransformerXLBlock, self).build(input_shape)

    def call(self,
             content_stream,
             mask = None,
             relative_position_encoding=None,
             state=None,
             content_attention_mask=None,
             query_attention_mask=None,
             target_mapping=None):
        
        attention_kwargs = dict(
                query=content_stream,
                value=content_stream,
                key=content_stream,
                state = None,
                attention_mask=mask)

        attention_output = self._attention_layer(**attention_kwargs)
        
        attention_stream = attention_output
        input_stream = content_stream
        attention_key = "content_attention"
        attention_output = {}
        
        attention_stream = self._attention_dropout(attention_stream)
        attention_stream = self._attention_layer_norm(attention_stream + input_stream)
        inner_output = self._inner_dense(attention_stream)
        inner_output = self._inner_activation_layer(
                inner_output)
        inner_output = self._inner_dropout_layer(
                inner_output)
        layer_output = self._output_dense(inner_output)
        layer_output = self._output_dropout(layer_output)
        layer_output = self._output_layer_norm(layer_output + attention_stream)
        attention_output[attention_key] = layer_output

        return attention_output

# %% [markdown]
# ---
# # Transformer XL

# %%
class TransformerXL(tf.keras.layers.Layer):
    def __init__(self,
                 vocab_size,
                 num_layers,
                 hidden_size,
                 maxlen,
                 embed_dim,
                 num_attention_heads,
                 head_size,
                 inner_size,
                 dropout_rate,
                 attention_dropout_rate,
                 initializer,
                 tie_attention_biases=True,
                 memory_length=None,
                 reuse_length=None,
                 inner_activation="relu",
                 **kwargs):
        super(TransformerXL, self).__init__(**kwargs)

        self._vocab_size = vocab_size
        self._initializer = initializer
        self._num_layers = num_layers
        self._hidden_size = hidden_size
        self._num_attention_heads = num_attention_heads
        self._head_size = head_size
        self._inner_size = inner_size
        self._inner_activation = inner_activation
        self._dropout_rate = dropout_rate
        self._attention_dropout_rate = attention_dropout_rate
        self._tie_attention_biases = tie_attention_biases

        self._memory_length = memory_length
        self._reuse_length = reuse_length

        if self._tie_attention_biases:
            attention_bias_shape = [self._num_attention_heads, self._head_size]
        else:
            attention_bias_shape = [self._num_layers, self._num_attention_heads, self._head_size]

        self.transformer_xl_layers = []
        
        for i in range(self._num_layers):
            self.transformer_xl_layers.append(
                    TransformerXLBlock(
                            vocab_size=self._vocab_size,
                            hidden_size=self._head_size * self._num_attention_heads,
                            num_attention_heads=self._num_attention_heads,
                            head_size=self._head_size,
                            inner_size=self._inner_size,
                            dropout_rate=self._dropout_rate,
                            attention_dropout_rate=self._attention_dropout_rate,
                            norm_epsilon=1e-12,
                            inner_activation=self._inner_activation,
                            kernel_initializer="variance_scaling",
                            name="layer_%d" % i))

        self.output_dropout = tf.keras.layers.Dropout(rate=self._dropout_rate)


    def call(self,
             content_stream,
             relative_position_encoding,
             mask, 
             state=None,
             content_attention_mask=None,
             query_attention_mask=None,
             target_mapping=None):
        
        new_mems = []

        if state is None:
            state = [None] * self._num_layers
        for i in range(self._num_layers):
            # cache new mems
            new_mems.append(_cache_memory(content_stream, state[i], self._memory_length, self._reuse_length))

            transformer_xl_layer = self.transformer_xl_layers[i]
            
            transformer_xl_output = transformer_xl_layer(
                    content_stream=content_stream,
                    mask=mask,
                    relative_position_encoding=relative_position_encoding,
                    state=state[i],
                    content_attention_mask=content_attention_mask,
                    query_attention_mask=query_attention_mask,
                    target_mapping=target_mapping)
            content_stream = transformer_xl_output["content_attention"]

        output_stream = content_stream
        return output_stream, new_mems

# %% [markdown]
# ---
# # Xl Model Class

# %%
class XlModel(keras.Model):
    def __init__(self, attention_block_size, max_files, encoder, block_size, seq_len_padded, embed_dim, vocab_size, num_layers, hidden_size, num_attention_heads, maxlen, memory_length, reuse_length, head_size, inner_size, dropout_rate, attention_dropout_rate, initializer):
        super(XlModel, self).__init__()
        
        self.block_size = block_size
        self.seq_len_padded = seq_len_padded
        self.embed_dim = embed_dim
        self.num_heads = num_attention_heads
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.maxlen = maxlen
        self.memory_length = memory_length
        self.max_files = max_files
        self.encoder = encoder
        self.isabs = []
        
        self.mask_layer = Create_BigBird_Masks(attention_block_size)
            
        self.embedding_layer = Create_Embeddings(encoder)

        self.linear_layer = keras.layers.Dense(self.embed_dim)
        
        self.transformer_xl = TransformerXL(
                vocab_size=vocab_size,
                num_layers=num_layers,
                hidden_size=hidden_size,
                num_attention_heads=num_attention_heads,
                maxlen=maxlen,
                embed_dim=embed_dim,
                memory_length=memory_length,
                reuse_length=reuse_length,
                head_size=head_size,
                inner_size=inner_size,
                dropout_rate=dropout_rate,
                attention_dropout_rate=attention_dropout_rate,
                initializer=initializer, 
            )
        

        self.pooling_layer = Set_Transformer.PoolingByMultiHeadAttention(num_seeds=1,embed_dim=embed_dim,num_heads=1,use_layernorm=True,pre_layernorm=True, use_keras_mha=True,is_final_block=True)
    
        self.reshape_layer = keras.layers.Reshape((embed_dim,))
   
        self.output_layer = keras.layers.Dense(self.max_files, activation=keras.activations.softmax)
        
    
    def call(self, x, training=None):        

        #mems = tf.zeros((self.num_layers, tf.shape(x)[0], self.memory_length, self.embed_dim))
        
        embeddings = self.embedding_layer(x)
            
        linear_transform = self.linear_layer(embeddings)    
        
#         for i in range(0, self.seq_len_padded, self.block_size):
            
#             block = embeddings[:,i:i+self.block_size]
            
#             mask = self.mask_layer(block)
            
#             output, mems = self.transformer_xl(content_stream=block, mask=mask, relative_position_encoding=None, state=None)

            
        mask = self.mask_layer(embeddings)

        output, mems = self.transformer_xl(content_stream=embeddings, mask=mask, relative_position_encoding=None, state=None)
                
        pooling = self.pooling_layer(output)

        reshape = self.reshape_layer(pooling)

        output = self.output_layer(reshape)          
        
        return output

# %% [markdown]
# ---
# # Attention Parameters

# %%
attention_block_size = 8

# %% [markdown]
# ---
# # Xl Parameters

# %%
#Xl Parameters 
embed_dim = 8
num_layers = 10
hidden_size = 32
num_attention_heads = 4
memory_length = 200
reuse_length = 0
head_size = 8
inner_size = 32
dropout_rate = 0.01
attention_dropout_rate = 0.01
initializer = keras.initializers.RandomNormal(stddev=0.1) 

encoder = pretrained_encoder
epochs = 10000

# %% [markdown]
# ---
# # Create Models

# %%
model = XlModel(attention_block_size, max_files, encoder, block_size, seq_len, embed_dim, vocab_size, num_layers, hidden_size, num_attention_heads, maxlen, memory_length, reuse_length, head_size, inner_size, dropout_rate, attention_dropout_rate, initializer)
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False), optimizer = keras.optimizers.Nadam(1e-4), metrics = keras.metrics.SparseCategoricalAccuracy())

# %%
(model(train_dataset[0][0])).shape
# Out:
# TensorShape([20, 49])

# %%
model.load_weights("./Saved_Models/Str_Xl_BigBird.h5")

# %%
history = model.fit(x=train_dataset, validation_data=val_dataset, epochs=epochs, verbose=1)
# Out:
# Epoch 1/10000
# WARNING:tensorflow:Gradients do not exist for variables ['xl_model_6/dense_41/kernel:0', 'xl_model_6/dense_41/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['xl_model_6/dense_41/kernel:0', 'xl_model_6/dense_41/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 20/20 [==============================] - 221s 10s/step - loss: 3.5766 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.5811 - val_sparse_categorical_accuracy: 0.0300
# Epoch 2/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5962 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.5867 - val_sparse_categorical_accuracy: 0.0500
# Epoch 3/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.6137 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.6580 - val_sparse_categorical_accuracy: 0.0450
# Epoch 4/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5874 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.5989 - val_sparse_categorical_accuracy: 0.0325
# Epoch 5/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.6088 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.6051 - val_sparse_categorical_accuracy: 0.0475
# Epoch 6/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5658 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.5880 - val_sparse_categorical_accuracy: 0.0450
# Epoch 7/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5792 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.6318 - val_sparse_categorical_accuracy: 0.0175
# Epoch 8/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.5807 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.5670 - val_sparse_categorical_accuracy: 0.0500
# Epoch 9/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5815 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.5443 - val_sparse_categorical_accuracy: 0.0325
# Epoch 10/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5580 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.5698 - val_sparse_categorical_accuracy: 0.0500
# Epoch 11/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5838 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.5656 - val_sparse_categorical_accuracy: 0.0325
# Epoch 12/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5601 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.5840 - val_sparse_categorical_accuracy: 0.0600
# Epoch 13/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5444 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.5429 - val_sparse_categorical_accuracy: 0.0325
# Epoch 14/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5559 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.5565 - val_sparse_categorical_accuracy: 0.0350
# Epoch 15/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5628 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.5321 - val_sparse_categorical_accuracy: 0.0475
# Epoch 16/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5597 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.5284 - val_sparse_categorical_accuracy: 0.0550
# Epoch 17/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5124 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.5735 - val_sparse_categorical_accuracy: 0.0300
# Epoch 18/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5416 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.5437 - val_sparse_categorical_accuracy: 0.0425
# Epoch 19/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5354 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.5549 - val_sparse_categorical_accuracy: 0.0350
# Epoch 20/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5261 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.5616 - val_sparse_categorical_accuracy: 0.0375
# Epoch 21/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5276 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.5388 - val_sparse_categorical_accuracy: 0.0425
# Epoch 22/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.5085 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.5264 - val_sparse_categorical_accuracy: 0.0300
# Epoch 23/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.5071 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.5099 - val_sparse_categorical_accuracy: 0.0550
# Epoch 24/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.5357 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.5439 - val_sparse_categorical_accuracy: 0.0400
# Epoch 25/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5282 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.5275 - val_sparse_categorical_accuracy: 0.0525
# Epoch 26/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5064 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.5186 - val_sparse_categorical_accuracy: 0.0300
# Epoch 27/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4706 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.5188 - val_sparse_categorical_accuracy: 0.0675
# Epoch 28/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4895 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.5093 - val_sparse_categorical_accuracy: 0.0425
# Epoch 29/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4853 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.4696 - val_sparse_categorical_accuracy: 0.0600
# Epoch 30/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5257 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.5003 - val_sparse_categorical_accuracy: 0.0300
# Epoch 31/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5072 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.4787 - val_sparse_categorical_accuracy: 0.0575
# Epoch 32/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5012 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.4801 - val_sparse_categorical_accuracy: 0.0475
# Epoch 33/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.5092 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.4727 - val_sparse_categorical_accuracy: 0.0500
# Epoch 34/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4971 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.4939 - val_sparse_categorical_accuracy: 0.0350
# Epoch 35/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.4876 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.4907 - val_sparse_categorical_accuracy: 0.0525
# Epoch 36/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4479 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.4712 - val_sparse_categorical_accuracy: 0.0550
# Epoch 37/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.4942 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.4910 - val_sparse_categorical_accuracy: 0.0275
# Epoch 38/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4605 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.4752 - val_sparse_categorical_accuracy: 0.0400
# Epoch 39/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4997 - sparse_categorical_accuracy: 0.0650 - val_loss: 3.4956 - val_sparse_categorical_accuracy: 0.0300
# Epoch 40/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.4748 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.4979 - val_sparse_categorical_accuracy: 0.0425
# Epoch 41/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4666 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.4561 - val_sparse_categorical_accuracy: 0.0400
# Epoch 42/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4859 - sparse_categorical_accuracy: 0.0225 - val_loss: 3.4718 - val_sparse_categorical_accuracy: 0.0275
# Epoch 43/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.4884 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.5032 - val_sparse_categorical_accuracy: 0.0450
# Epoch 44/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4631 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.4635 - val_sparse_categorical_accuracy: 0.0350
# Epoch 45/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4534 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.4458 - val_sparse_categorical_accuracy: 0.0425
# Epoch 46/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4508 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.4393 - val_sparse_categorical_accuracy: 0.0425
# Epoch 47/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4383 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.4615 - val_sparse_categorical_accuracy: 0.0725
# Epoch 48/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4800 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.4594 - val_sparse_categorical_accuracy: 0.0900
# Epoch 49/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.4318 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.4429 - val_sparse_categorical_accuracy: 0.0500
# Epoch 50/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4411 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.4388 - val_sparse_categorical_accuracy: 0.0725
# Epoch 51/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4553 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.4359 - val_sparse_categorical_accuracy: 0.0600
# Epoch 52/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4258 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.4416 - val_sparse_categorical_accuracy: 0.0600
# Epoch 53/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4288 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.4544 - val_sparse_categorical_accuracy: 0.0225
# Epoch 54/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4353 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.4180 - val_sparse_categorical_accuracy: 0.0350
# Epoch 55/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4294 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.4397 - val_sparse_categorical_accuracy: 0.0650
# Epoch 56/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4106 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.4391 - val_sparse_categorical_accuracy: 0.0775
# Epoch 57/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4401 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.4429 - val_sparse_categorical_accuracy: 0.0225
# Epoch 58/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4196 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.4293 - val_sparse_categorical_accuracy: 0.0450
# Epoch 59/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4267 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.4396 - val_sparse_categorical_accuracy: 0.0450
# Epoch 60/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4182 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.4128 - val_sparse_categorical_accuracy: 0.0625
# Epoch 61/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4440 - sparse_categorical_accuracy: 0.0175 - val_loss: 3.4421 - val_sparse_categorical_accuracy: 0.0500
# Epoch 62/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4325 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.4122 - val_sparse_categorical_accuracy: 0.0525
# Epoch 63/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3855 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.4260 - val_sparse_categorical_accuracy: 0.0350
# Epoch 64/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4513 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.4061 - val_sparse_categorical_accuracy: 0.0500
# Epoch 65/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4160 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.4181 - val_sparse_categorical_accuracy: 0.0500
# Epoch 66/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3989 - sparse_categorical_accuracy: 0.0650 - val_loss: 3.4267 - val_sparse_categorical_accuracy: 0.0375
# Epoch 67/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3947 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.4199 - val_sparse_categorical_accuracy: 0.0550
# Epoch 68/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3843 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.4075 - val_sparse_categorical_accuracy: 0.0375
# Epoch 69/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4054 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.4182 - val_sparse_categorical_accuracy: 0.0550
# Epoch 70/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.4042 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.3845 - val_sparse_categorical_accuracy: 0.0475
# Epoch 71/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3787 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.4160 - val_sparse_categorical_accuracy: 0.0700
# Epoch 72/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3965 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.4068 - val_sparse_categorical_accuracy: 0.0675
# Epoch 73/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3932 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.3977 - val_sparse_categorical_accuracy: 0.0500
# Epoch 74/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3990 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.3802 - val_sparse_categorical_accuracy: 0.0600
# Epoch 75/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3710 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.3866 - val_sparse_categorical_accuracy: 0.0225
# Epoch 76/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3943 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.3776 - val_sparse_categorical_accuracy: 0.0525
# Epoch 77/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3876 - sparse_categorical_accuracy: 0.0700 - val_loss: 3.3863 - val_sparse_categorical_accuracy: 0.0550
# Epoch 78/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3930 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.3937 - val_sparse_categorical_accuracy: 0.0725
# Epoch 79/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3814 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.4120 - val_sparse_categorical_accuracy: 0.0625
# Epoch 80/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3646 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.3835 - val_sparse_categorical_accuracy: 0.0700
# Epoch 81/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3873 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.3732 - val_sparse_categorical_accuracy: 0.0700
# Epoch 82/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3611 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.3665 - val_sparse_categorical_accuracy: 0.0625
# Epoch 83/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3925 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.3610 - val_sparse_categorical_accuracy: 0.0675
# Epoch 84/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3939 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.3362 - val_sparse_categorical_accuracy: 0.0600
# Epoch 85/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3692 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.3445 - val_sparse_categorical_accuracy: 0.0825
# Epoch 86/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3499 - sparse_categorical_accuracy: 0.0775 - val_loss: 3.3610 - val_sparse_categorical_accuracy: 0.0725
# Epoch 87/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3574 - sparse_categorical_accuracy: 0.0825 - val_loss: 3.3806 - val_sparse_categorical_accuracy: 0.0600
# Epoch 88/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3449 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.3823 - val_sparse_categorical_accuracy: 0.0725
# Epoch 89/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3664 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.3752 - val_sparse_categorical_accuracy: 0.0500
# Epoch 90/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3586 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.4281 - val_sparse_categorical_accuracy: 0.0650
# Epoch 91/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3896 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.3460 - val_sparse_categorical_accuracy: 0.0700
# Epoch 92/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3639 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.3601 - val_sparse_categorical_accuracy: 0.0625
# Epoch 93/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3442 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.3414 - val_sparse_categorical_accuracy: 0.0625
# Epoch 94/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3643 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.3880 - val_sparse_categorical_accuracy: 0.0700
# Epoch 95/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3543 - sparse_categorical_accuracy: 0.0725 - val_loss: 3.3377 - val_sparse_categorical_accuracy: 0.0750
# Epoch 96/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3381 - sparse_categorical_accuracy: 0.0900 - val_loss: 3.3379 - val_sparse_categorical_accuracy: 0.0550
# Epoch 97/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3504 - sparse_categorical_accuracy: 0.0650 - val_loss: 3.3522 - val_sparse_categorical_accuracy: 0.0950
# Epoch 98/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3267 - sparse_categorical_accuracy: 0.0800 - val_loss: 3.3453 - val_sparse_categorical_accuracy: 0.0625
# Epoch 99/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3447 - sparse_categorical_accuracy: 0.0650 - val_loss: 3.3707 - val_sparse_categorical_accuracy: 0.0350
# Epoch 100/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3256 - sparse_categorical_accuracy: 0.0675 - val_loss: 3.3287 - val_sparse_categorical_accuracy: 0.1100
# Epoch 101/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3399 - sparse_categorical_accuracy: 0.0650 - val_loss: 3.3437 - val_sparse_categorical_accuracy: 0.0850
# Epoch 102/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3119 - sparse_categorical_accuracy: 0.0825 - val_loss: 3.3408 - val_sparse_categorical_accuracy: 0.0825
# Epoch 103/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3175 - sparse_categorical_accuracy: 0.0675 - val_loss: 3.3029 - val_sparse_categorical_accuracy: 0.0875
# Epoch 104/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3310 - sparse_categorical_accuracy: 0.0700 - val_loss: 3.3143 - val_sparse_categorical_accuracy: 0.1000
# Epoch 105/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3415 - sparse_categorical_accuracy: 0.0950 - val_loss: 3.3473 - val_sparse_categorical_accuracy: 0.0775
# Epoch 106/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3203 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.2834 - val_sparse_categorical_accuracy: 0.1225
# Epoch 107/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3414 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.3858 - val_sparse_categorical_accuracy: 0.0625
# Epoch 108/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3243 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.3043 - val_sparse_categorical_accuracy: 0.1025
# Epoch 109/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3132 - sparse_categorical_accuracy: 0.0850 - val_loss: 3.3268 - val_sparse_categorical_accuracy: 0.0750
# Epoch 110/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3087 - sparse_categorical_accuracy: 0.0750 - val_loss: 3.3113 - val_sparse_categorical_accuracy: 0.0550
# Epoch 111/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2914 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.3104 - val_sparse_categorical_accuracy: 0.1050
# Epoch 112/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3020 - sparse_categorical_accuracy: 0.0900 - val_loss: 3.2831 - val_sparse_categorical_accuracy: 0.1225
# Epoch 113/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3103 - sparse_categorical_accuracy: 0.0800 - val_loss: 3.3300 - val_sparse_categorical_accuracy: 0.0750
# Epoch 114/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3155 - sparse_categorical_accuracy: 0.0700 - val_loss: 3.2960 - val_sparse_categorical_accuracy: 0.0900
# Epoch 115/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3102 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.2942 - val_sparse_categorical_accuracy: 0.1175
# Epoch 116/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3083 - sparse_categorical_accuracy: 0.0700 - val_loss: 3.3046 - val_sparse_categorical_accuracy: 0.0850
# Epoch 117/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2972 - sparse_categorical_accuracy: 0.0825 - val_loss: 3.2917 - val_sparse_categorical_accuracy: 0.0975
# Epoch 118/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3059 - sparse_categorical_accuracy: 0.0725 - val_loss: 3.2781 - val_sparse_categorical_accuracy: 0.1150
# Epoch 119/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2798 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.2869 - val_sparse_categorical_accuracy: 0.1075
# Epoch 120/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3000 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.3478 - val_sparse_categorical_accuracy: 0.0650
# Epoch 121/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.3113 - sparse_categorical_accuracy: 0.0875 - val_loss: 3.3121 - val_sparse_categorical_accuracy: 0.0775
# Epoch 122/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2973 - sparse_categorical_accuracy: 0.0850 - val_loss: 3.3064 - val_sparse_categorical_accuracy: 0.0775
# Epoch 123/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2767 - sparse_categorical_accuracy: 0.0850 - val_loss: 3.2731 - val_sparse_categorical_accuracy: 0.0975
# Epoch 124/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.3110 - sparse_categorical_accuracy: 0.0900 - val_loss: 3.2727 - val_sparse_categorical_accuracy: 0.1300
# Epoch 125/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2842 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.2814 - val_sparse_categorical_accuracy: 0.0750
# Epoch 126/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2596 - sparse_categorical_accuracy: 0.1250 - val_loss: 3.3713 - val_sparse_categorical_accuracy: 0.0500
# Epoch 127/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2797 - sparse_categorical_accuracy: 0.0750 - val_loss: 3.3078 - val_sparse_categorical_accuracy: 0.1100
# Epoch 128/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2732 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.2721 - val_sparse_categorical_accuracy: 0.1000
# Epoch 129/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2817 - sparse_categorical_accuracy: 0.0775 - val_loss: 3.2477 - val_sparse_categorical_accuracy: 0.1300
# Epoch 130/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2832 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.3008 - val_sparse_categorical_accuracy: 0.0975
# Epoch 131/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2720 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.2566 - val_sparse_categorical_accuracy: 0.0850
# Epoch 132/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2492 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.2942 - val_sparse_categorical_accuracy: 0.0575
# Epoch 133/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2870 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.2890 - val_sparse_categorical_accuracy: 0.1000
# Epoch 134/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2807 - sparse_categorical_accuracy: 0.0975 - val_loss: 3.3172 - val_sparse_categorical_accuracy: 0.0600
# Epoch 135/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2667 - sparse_categorical_accuracy: 0.0850 - val_loss: 3.2712 - val_sparse_categorical_accuracy: 0.1050
# Epoch 136/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2671 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.3033 - val_sparse_categorical_accuracy: 0.0725
# Epoch 137/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2873 - sparse_categorical_accuracy: 0.0725 - val_loss: 3.2660 - val_sparse_categorical_accuracy: 0.0725
# Epoch 138/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2544 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.2727 - val_sparse_categorical_accuracy: 0.1050
# Epoch 139/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2411 - sparse_categorical_accuracy: 0.1300 - val_loss: 3.2623 - val_sparse_categorical_accuracy: 0.1000
# Epoch 140/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2686 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.2863 - val_sparse_categorical_accuracy: 0.0875
# Epoch 141/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2615 - sparse_categorical_accuracy: 0.0900 - val_loss: 3.2740 - val_sparse_categorical_accuracy: 0.0875
# Epoch 142/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2560 - sparse_categorical_accuracy: 0.0975 - val_loss: 3.2789 - val_sparse_categorical_accuracy: 0.0700
# Epoch 143/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2244 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.2715 - val_sparse_categorical_accuracy: 0.1200
# Epoch 144/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2495 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.2316 - val_sparse_categorical_accuracy: 0.1075
# Epoch 145/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2431 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.2453 - val_sparse_categorical_accuracy: 0.1125
# Epoch 146/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2404 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.2411 - val_sparse_categorical_accuracy: 0.1175
# Epoch 147/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2564 - sparse_categorical_accuracy: 0.0800 - val_loss: 3.2341 - val_sparse_categorical_accuracy: 0.1175
# Epoch 148/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2285 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.2508 - val_sparse_categorical_accuracy: 0.1275
# Epoch 149/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2420 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.2299 - val_sparse_categorical_accuracy: 0.1250
# Epoch 150/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2364 - sparse_categorical_accuracy: 0.0900 - val_loss: 3.2535 - val_sparse_categorical_accuracy: 0.1075
# Epoch 151/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2081 - sparse_categorical_accuracy: 0.1375 - val_loss: 3.2527 - val_sparse_categorical_accuracy: 0.1025
# Epoch 152/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2268 - sparse_categorical_accuracy: 0.0975 - val_loss: 3.2620 - val_sparse_categorical_accuracy: 0.1125
# Epoch 153/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2438 - sparse_categorical_accuracy: 0.1225 - val_loss: 3.2208 - val_sparse_categorical_accuracy: 0.1200
# Epoch 154/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2195 - sparse_categorical_accuracy: 0.1375 - val_loss: 3.2864 - val_sparse_categorical_accuracy: 0.0900
# Epoch 155/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2206 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.2661 - val_sparse_categorical_accuracy: 0.0800
# Epoch 156/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2363 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.2265 - val_sparse_categorical_accuracy: 0.1225
# Epoch 157/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2085 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.2527 - val_sparse_categorical_accuracy: 0.0900
# Epoch 158/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2221 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.2521 - val_sparse_categorical_accuracy: 0.1125
# Epoch 159/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2245 - sparse_categorical_accuracy: 0.1275 - val_loss: 3.2350 - val_sparse_categorical_accuracy: 0.1150
# Epoch 160/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2263 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.2537 - val_sparse_categorical_accuracy: 0.1100
# Epoch 161/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2207 - sparse_categorical_accuracy: 0.0850 - val_loss: 3.2622 - val_sparse_categorical_accuracy: 0.0900
# Epoch 162/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2115 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.2572 - val_sparse_categorical_accuracy: 0.1050
# Epoch 163/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2080 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.2386 - val_sparse_categorical_accuracy: 0.0925
# Epoch 164/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2230 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.2497 - val_sparse_categorical_accuracy: 0.0850
# Epoch 165/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2097 - sparse_categorical_accuracy: 0.1100 - val_loss: 3.1738 - val_sparse_categorical_accuracy: 0.1400
# Epoch 166/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2089 - sparse_categorical_accuracy: 0.1150 - val_loss: 3.2380 - val_sparse_categorical_accuracy: 0.1075
# Epoch 167/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1989 - sparse_categorical_accuracy: 0.1275 - val_loss: 3.2298 - val_sparse_categorical_accuracy: 0.1050
# Epoch 168/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2385 - sparse_categorical_accuracy: 0.0800 - val_loss: 3.2261 - val_sparse_categorical_accuracy: 0.1225
# Epoch 169/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2153 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.2351 - val_sparse_categorical_accuracy: 0.0950
# Epoch 170/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2124 - sparse_categorical_accuracy: 0.0825 - val_loss: 3.2488 - val_sparse_categorical_accuracy: 0.1075
# Epoch 171/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1799 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.1845 - val_sparse_categorical_accuracy: 0.1350
# Epoch 172/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1979 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.2617 - val_sparse_categorical_accuracy: 0.0975
# Epoch 173/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.2052 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.2145 - val_sparse_categorical_accuracy: 0.0975
# Epoch 174/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2125 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.1868 - val_sparse_categorical_accuracy: 0.1225
# Epoch 175/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1834 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.2001 - val_sparse_categorical_accuracy: 0.0925
# Epoch 176/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2017 - sparse_categorical_accuracy: 0.0875 - val_loss: 3.2158 - val_sparse_categorical_accuracy: 0.0925
# Epoch 177/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2103 - sparse_categorical_accuracy: 0.0950 - val_loss: 3.2334 - val_sparse_categorical_accuracy: 0.0700
# Epoch 178/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2122 - sparse_categorical_accuracy: 0.0900 - val_loss: 3.1925 - val_sparse_categorical_accuracy: 0.1125
# Epoch 179/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1846 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.2156 - val_sparse_categorical_accuracy: 0.0750
# Epoch 180/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.2014 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.2083 - val_sparse_categorical_accuracy: 0.1075
# Epoch 181/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1849 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.2005 - val_sparse_categorical_accuracy: 0.1025
# Epoch 182/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1716 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.1898 - val_sparse_categorical_accuracy: 0.0975
# Epoch 183/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1726 - sparse_categorical_accuracy: 0.1275 - val_loss: 3.2172 - val_sparse_categorical_accuracy: 0.0950
# Epoch 184/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1941 - sparse_categorical_accuracy: 0.0825 - val_loss: 3.2172 - val_sparse_categorical_accuracy: 0.1075
# Epoch 185/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1744 - sparse_categorical_accuracy: 0.0975 - val_loss: 3.2406 - val_sparse_categorical_accuracy: 0.0975
# Epoch 186/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1558 - sparse_categorical_accuracy: 0.1225 - val_loss: 3.2449 - val_sparse_categorical_accuracy: 0.0975
# Epoch 187/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1792 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.1862 - val_sparse_categorical_accuracy: 0.1150
# Epoch 188/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1805 - sparse_categorical_accuracy: 0.0825 - val_loss: 3.2595 - val_sparse_categorical_accuracy: 0.0875
# Epoch 189/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1526 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.2247 - val_sparse_categorical_accuracy: 0.0850
# Epoch 190/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1906 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.1524 - val_sparse_categorical_accuracy: 0.1200
# Epoch 191/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1775 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.1645 - val_sparse_categorical_accuracy: 0.1175
# Epoch 192/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1912 - sparse_categorical_accuracy: 0.1000 - val_loss: 3.1527 - val_sparse_categorical_accuracy: 0.1350
# Epoch 193/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1591 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.1873 - val_sparse_categorical_accuracy: 0.1075
# Epoch 194/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1526 - sparse_categorical_accuracy: 0.1375 - val_loss: 3.2464 - val_sparse_categorical_accuracy: 0.0825
# Epoch 195/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1828 - sparse_categorical_accuracy: 0.0950 - val_loss: 3.1945 - val_sparse_categorical_accuracy: 0.1050
# Epoch 196/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1510 - sparse_categorical_accuracy: 0.1275 - val_loss: 3.1750 - val_sparse_categorical_accuracy: 0.1250
# Epoch 197/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1587 - sparse_categorical_accuracy: 0.1150 - val_loss: 3.1849 - val_sparse_categorical_accuracy: 0.1075
# Epoch 198/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1660 - sparse_categorical_accuracy: 0.1300 - val_loss: 3.2062 - val_sparse_categorical_accuracy: 0.0975
# Epoch 199/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1392 - sparse_categorical_accuracy: 0.1375 - val_loss: 3.1786 - val_sparse_categorical_accuracy: 0.1200
# Epoch 200/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1583 - sparse_categorical_accuracy: 0.0950 - val_loss: 3.1738 - val_sparse_categorical_accuracy: 0.1275
# Epoch 201/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1415 - sparse_categorical_accuracy: 0.0950 - val_loss: 3.1569 - val_sparse_categorical_accuracy: 0.1375
# Epoch 202/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1598 - sparse_categorical_accuracy: 0.1250 - val_loss: 3.1894 - val_sparse_categorical_accuracy: 0.0975
# Epoch 203/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1487 - sparse_categorical_accuracy: 0.1325 - val_loss: 3.1325 - val_sparse_categorical_accuracy: 0.1325
# Epoch 204/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1171 - sparse_categorical_accuracy: 0.1450 - val_loss: 3.1490 - val_sparse_categorical_accuracy: 0.1400
# Epoch 205/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1617 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.1414 - val_sparse_categorical_accuracy: 0.1200
# Epoch 206/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1584 - sparse_categorical_accuracy: 0.0900 - val_loss: 3.1276 - val_sparse_categorical_accuracy: 0.1250
# Epoch 207/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1596 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.1845 - val_sparse_categorical_accuracy: 0.1100
# Epoch 208/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1442 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.1264 - val_sparse_categorical_accuracy: 0.1375
# Epoch 209/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1372 - sparse_categorical_accuracy: 0.1250 - val_loss: 3.1336 - val_sparse_categorical_accuracy: 0.1175
# Epoch 210/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1403 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.1631 - val_sparse_categorical_accuracy: 0.1025
# Epoch 211/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1445 - sparse_categorical_accuracy: 0.1100 - val_loss: 3.1262 - val_sparse_categorical_accuracy: 0.1375
# Epoch 212/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1464 - sparse_categorical_accuracy: 0.0975 - val_loss: 3.1179 - val_sparse_categorical_accuracy: 0.1300
# Epoch 213/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0966 - sparse_categorical_accuracy: 0.1350 - val_loss: 3.2241 - val_sparse_categorical_accuracy: 0.1125
# Epoch 214/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1235 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.1344 - val_sparse_categorical_accuracy: 0.1125
# Epoch 215/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1383 - sparse_categorical_accuracy: 0.0825 - val_loss: 3.1789 - val_sparse_categorical_accuracy: 0.1150
# Epoch 216/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1252 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.1217 - val_sparse_categorical_accuracy: 0.1225
# Epoch 217/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1232 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.1557 - val_sparse_categorical_accuracy: 0.1100
# Epoch 218/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1258 - sparse_categorical_accuracy: 0.1250 - val_loss: 3.1214 - val_sparse_categorical_accuracy: 0.1350
# Epoch 219/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0955 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.1096 - val_sparse_categorical_accuracy: 0.1125
# Epoch 220/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1133 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.1657 - val_sparse_categorical_accuracy: 0.1125
# Epoch 221/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1303 - sparse_categorical_accuracy: 0.0950 - val_loss: 3.1441 - val_sparse_categorical_accuracy: 0.1100
# Epoch 222/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0948 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.1928 - val_sparse_categorical_accuracy: 0.0825
# Epoch 223/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1231 - sparse_categorical_accuracy: 0.1150 - val_loss: 3.1443 - val_sparse_categorical_accuracy: 0.0900
# Epoch 224/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1060 - sparse_categorical_accuracy: 0.0975 - val_loss: 3.1065 - val_sparse_categorical_accuracy: 0.0900
# Epoch 225/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1069 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.1318 - val_sparse_categorical_accuracy: 0.1275
# Epoch 226/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1301 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.1141 - val_sparse_categorical_accuracy: 0.1225
# Epoch 227/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1213 - sparse_categorical_accuracy: 0.1000 - val_loss: 3.1265 - val_sparse_categorical_accuracy: 0.0975
# Epoch 228/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1090 - sparse_categorical_accuracy: 0.1150 - val_loss: 3.1148 - val_sparse_categorical_accuracy: 0.1350
# Epoch 229/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1112 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.0845 - val_sparse_categorical_accuracy: 0.1150
# Epoch 230/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0793 - sparse_categorical_accuracy: 0.1275 - val_loss: 3.0890 - val_sparse_categorical_accuracy: 0.1200
# Epoch 231/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0942 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.0996 - val_sparse_categorical_accuracy: 0.1150
# Epoch 232/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0874 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.1197 - val_sparse_categorical_accuracy: 0.0950
# Epoch 233/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1074 - sparse_categorical_accuracy: 0.1000 - val_loss: 3.1275 - val_sparse_categorical_accuracy: 0.0925
# Epoch 234/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.1239 - sparse_categorical_accuracy: 0.1325 - val_loss: 3.1189 - val_sparse_categorical_accuracy: 0.1350
# Epoch 235/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0911 - sparse_categorical_accuracy: 0.1275 - val_loss: 3.0766 - val_sparse_categorical_accuracy: 0.1400
# Epoch 236/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0947 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.0881 - val_sparse_categorical_accuracy: 0.1150
# Epoch 237/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0875 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.0793 - val_sparse_categorical_accuracy: 0.1300
# Epoch 238/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0950 - sparse_categorical_accuracy: 0.0900 - val_loss: 3.1106 - val_sparse_categorical_accuracy: 0.0950
# Epoch 239/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1018 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.1318 - val_sparse_categorical_accuracy: 0.1150
# Epoch 240/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1017 - sparse_categorical_accuracy: 0.1100 - val_loss: 3.0733 - val_sparse_categorical_accuracy: 0.1375
# Epoch 241/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0858 - sparse_categorical_accuracy: 0.1000 - val_loss: 3.0804 - val_sparse_categorical_accuracy: 0.1125
# Epoch 242/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0654 - sparse_categorical_accuracy: 0.1225 - val_loss: 3.0358 - val_sparse_categorical_accuracy: 0.1250
# Epoch 243/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0702 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.0638 - val_sparse_categorical_accuracy: 0.1900
# Epoch 244/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1054 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.0819 - val_sparse_categorical_accuracy: 0.1375
# Epoch 245/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0611 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.0376 - val_sparse_categorical_accuracy: 0.1425
# Epoch 246/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0685 - sparse_categorical_accuracy: 0.1250 - val_loss: 3.0714 - val_sparse_categorical_accuracy: 0.1600
# Epoch 247/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0570 - sparse_categorical_accuracy: 0.1225 - val_loss: 3.0451 - val_sparse_categorical_accuracy: 0.0950
# Epoch 248/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0653 - sparse_categorical_accuracy: 0.1350 - val_loss: 3.0565 - val_sparse_categorical_accuracy: 0.1450
# Epoch 249/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0538 - sparse_categorical_accuracy: 0.1100 - val_loss: 3.1018 - val_sparse_categorical_accuracy: 0.1350
# Epoch 250/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.1069 - sparse_categorical_accuracy: 0.0850 - val_loss: 3.1039 - val_sparse_categorical_accuracy: 0.1250
# Epoch 251/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0716 - sparse_categorical_accuracy: 0.1100 - val_loss: 3.0297 - val_sparse_categorical_accuracy: 0.1475
# Epoch 252/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0535 - sparse_categorical_accuracy: 0.1050 - val_loss: 3.0952 - val_sparse_categorical_accuracy: 0.1200
# Epoch 253/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0880 - sparse_categorical_accuracy: 0.0925 - val_loss: 3.0608 - val_sparse_categorical_accuracy: 0.1850
# Epoch 254/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0753 - sparse_categorical_accuracy: 0.1150 - val_loss: 3.1013 - val_sparse_categorical_accuracy: 0.1000
# Epoch 255/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0887 - sparse_categorical_accuracy: 0.1100 - val_loss: 3.0329 - val_sparse_categorical_accuracy: 0.1425
# Epoch 256/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0536 - sparse_categorical_accuracy: 0.1300 - val_loss: 3.0184 - val_sparse_categorical_accuracy: 0.1650
# Epoch 257/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0590 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.0680 - val_sparse_categorical_accuracy: 0.0850
# Epoch 258/10000
# ...
# Epoch 268/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0271 - sparse_categorical_accuracy: 0.1025 - val_loss: 3.0319 - val_sparse_categorical_accuracy: 0.1325
# Epoch 269/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0620 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.0877 - val_sparse_categorical_accuracy: 0.1425
# Epoch 270/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0133 - sparse_categorical_accuracy: 0.1500 - val_loss: 3.0208 - val_sparse_categorical_accuracy: 0.1250
# Epoch 271/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0278 - sparse_categorical_accuracy: 0.1125 - val_loss: 3.0014 - val_sparse_categorical_accuracy: 0.1700
# Epoch 272/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0485 - sparse_categorical_accuracy: 0.1250 - val_loss: 3.0927 - val_sparse_categorical_accuracy: 0.0975
# Epoch 273/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0417 - sparse_categorical_accuracy: 0.1400 - val_loss: 3.0179 - val_sparse_categorical_accuracy: 0.1700
# Epoch 274/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0215 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.0184 - val_sparse_categorical_accuracy: 0.1425
# Epoch 275/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0147 - sparse_categorical_accuracy: 0.1425 - val_loss: 2.9807 - val_sparse_categorical_accuracy: 0.1625
# Epoch 276/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9755 - sparse_categorical_accuracy: 0.1325 - val_loss: 3.0565 - val_sparse_categorical_accuracy: 0.1575
# Epoch 277/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0321 - sparse_categorical_accuracy: 0.1575 - val_loss: 3.0029 - val_sparse_categorical_accuracy: 0.1500
# Epoch 278/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0401 - sparse_categorical_accuracy: 0.1550 - val_loss: 2.9837 - val_sparse_categorical_accuracy: 0.1275
# Epoch 279/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0184 - sparse_categorical_accuracy: 0.1275 - val_loss: 3.0107 - val_sparse_categorical_accuracy: 0.1375
# Epoch 280/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9966 - sparse_categorical_accuracy: 0.1575 - val_loss: 3.0136 - val_sparse_categorical_accuracy: 0.1125
# Epoch 281/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0013 - sparse_categorical_accuracy: 0.1275 - val_loss: 3.0015 - val_sparse_categorical_accuracy: 0.1650
# Epoch 282/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0074 - sparse_categorical_accuracy: 0.1625 - val_loss: 2.9683 - val_sparse_categorical_accuracy: 0.1600
# Epoch 283/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0023 - sparse_categorical_accuracy: 0.1675 - val_loss: 2.9982 - val_sparse_categorical_accuracy: 0.1475
# Epoch 284/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0332 - sparse_categorical_accuracy: 0.1375 - val_loss: 3.0098 - val_sparse_categorical_accuracy: 0.1025
# Epoch 285/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9733 - sparse_categorical_accuracy: 0.1175 - val_loss: 3.0281 - val_sparse_categorical_accuracy: 0.1175
# Epoch 286/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0088 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.0108 - val_sparse_categorical_accuracy: 0.1125
# Epoch 287/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0062 - sparse_categorical_accuracy: 0.1200 - val_loss: 3.0118 - val_sparse_categorical_accuracy: 0.1150
# Epoch 288/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0092 - sparse_categorical_accuracy: 0.1300 - val_loss: 2.9919 - val_sparse_categorical_accuracy: 0.1200
# Epoch 289/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9987 - sparse_categorical_accuracy: 0.1225 - val_loss: 2.9900 - val_sparse_categorical_accuracy: 0.1100
# Epoch 290/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0417 - sparse_categorical_accuracy: 0.1250 - val_loss: 3.0111 - val_sparse_categorical_accuracy: 0.1250
# Epoch 291/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0091 - sparse_categorical_accuracy: 0.1075 - val_loss: 3.0424 - val_sparse_categorical_accuracy: 0.0950
# Epoch 292/10000
# 20/20 [==============================] - 190s 10s/step - loss: 3.0044 - sparse_categorical_accuracy: 0.1300 - val_loss: 2.9983 - val_sparse_categorical_accuracy: 0.1550
# Epoch 293/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9830 - sparse_categorical_accuracy: 0.1350 - val_loss: 3.0439 - val_sparse_categorical_accuracy: 0.1275
# Epoch 294/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9710 - sparse_categorical_accuracy: 0.1275 - val_loss: 2.9807 - val_sparse_categorical_accuracy: 0.1850
# Epoch 295/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9958 - sparse_categorical_accuracy: 0.1200 - val_loss: 2.9623 - val_sparse_categorical_accuracy: 0.1425
# Epoch 296/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9855 - sparse_categorical_accuracy: 0.1375 - val_loss: 3.0218 - val_sparse_categorical_accuracy: 0.1200
# Epoch 297/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9723 - sparse_categorical_accuracy: 0.1350 - val_loss: 3.0785 - val_sparse_categorical_accuracy: 0.1075
# Epoch 298/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9622 - sparse_categorical_accuracy: 0.1475 - val_loss: 2.9709 - val_sparse_categorical_accuracy: 0.1550
# Epoch 299/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9600 - sparse_categorical_accuracy: 0.1325 - val_loss: 3.0171 - val_sparse_categorical_accuracy: 0.1325
# Epoch 300/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9738 - sparse_categorical_accuracy: 0.1675 - val_loss: 2.9446 - val_sparse_categorical_accuracy: 0.1525
# Epoch 301/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9781 - sparse_categorical_accuracy: 0.1625 - val_loss: 2.9826 - val_sparse_categorical_accuracy: 0.1400
# Epoch 302/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9989 - sparse_categorical_accuracy: 0.1300 - val_loss: 2.9563 - val_sparse_categorical_accuracy: 0.1575
# Epoch 303/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9691 - sparse_categorical_accuracy: 0.1550 - val_loss: 2.9804 - val_sparse_categorical_accuracy: 0.1425
# Epoch 304/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9672 - sparse_categorical_accuracy: 0.1450 - val_loss: 3.0005 - val_sparse_categorical_accuracy: 0.1150
# Epoch 305/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9675 - sparse_categorical_accuracy: 0.1500 - val_loss: 3.0446 - val_sparse_categorical_accuracy: 0.0975
# Epoch 306/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9949 - sparse_categorical_accuracy: 0.1425 - val_loss: 2.9648 - val_sparse_categorical_accuracy: 0.1375
# Epoch 307/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9670 - sparse_categorical_accuracy: 0.1275 - val_loss: 2.9233 - val_sparse_categorical_accuracy: 0.1425
# Epoch 308/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9712 - sparse_categorical_accuracy: 0.1550 - val_loss: 2.9670 - val_sparse_categorical_accuracy: 0.1375
# Epoch 309/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9449 - sparse_categorical_accuracy: 0.1550 - val_loss: 2.9860 - val_sparse_categorical_accuracy: 0.1700
# Epoch 310/10000
# 20/20 [==============================] - 189s 10s/step - loss: 3.0041 - sparse_categorical_accuracy: 0.1300 - val_loss: 2.9453 - val_sparse_categorical_accuracy: 0.1825
# Epoch 311/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9558 - sparse_categorical_accuracy: 0.1475 - val_loss: 2.9586 - val_sparse_categorical_accuracy: 0.1325
# Epoch 312/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9799 - sparse_categorical_accuracy: 0.1300 - val_loss: 2.9702 - val_sparse_categorical_accuracy: 0.1525
# Epoch 313/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9857 - sparse_categorical_accuracy: 0.1500 - val_loss: 3.0654 - val_sparse_categorical_accuracy: 0.0875
# Epoch 314/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9777 - sparse_categorical_accuracy: 0.1275 - val_loss: 2.9432 - val_sparse_categorical_accuracy: 0.1450
# Epoch 315/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9725 - sparse_categorical_accuracy: 0.1450 - val_loss: 2.9698 - val_sparse_categorical_accuracy: 0.1275
# Epoch 316/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9534 - sparse_categorical_accuracy: 0.1500 - val_loss: 2.9715 - val_sparse_categorical_accuracy: 0.1200
# Epoch 317/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9665 - sparse_categorical_accuracy: 0.1375 - val_loss: 2.9597 - val_sparse_categorical_accuracy: 0.1250
# Epoch 318/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9576 - sparse_categorical_accuracy: 0.1375 - val_loss: 2.9228 - val_sparse_categorical_accuracy: 0.1825
# Epoch 319/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9464 - sparse_categorical_accuracy: 0.1575 - val_loss: 2.9932 - val_sparse_categorical_accuracy: 0.1400
# Epoch 320/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9435 - sparse_categorical_accuracy: 0.1575 - val_loss: 2.9168 - val_sparse_categorical_accuracy: 0.1600
# Epoch 321/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9385 - sparse_categorical_accuracy: 0.1700 - val_loss: 2.9249 - val_sparse_categorical_accuracy: 0.1950
# Epoch 322/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9370 - sparse_categorical_accuracy: 0.1500 - val_loss: 2.8865 - val_sparse_categorical_accuracy: 0.1650
# Epoch 323/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9351 - sparse_categorical_accuracy: 0.1800 - val_loss: 2.9446 - val_sparse_categorical_accuracy: 0.1425
# Epoch 324/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9998 - sparse_categorical_accuracy: 0.1350 - val_loss: 2.9198 - val_sparse_categorical_accuracy: 0.1525
# Epoch 325/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9565 - sparse_categorical_accuracy: 0.1425 - val_loss: 2.9055 - val_sparse_categorical_accuracy: 0.1425
# Epoch 326/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9210 - sparse_categorical_accuracy: 0.1375 - val_loss: 2.9182 - val_sparse_categorical_accuracy: 0.1450
# Epoch 327/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9145 - sparse_categorical_accuracy: 0.1575 - val_loss: 2.9675 - val_sparse_categorical_accuracy: 0.1375
# Epoch 328/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9435 - sparse_categorical_accuracy: 0.1500 - val_loss: 2.9425 - val_sparse_categorical_accuracy: 0.1625
# Epoch 329/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9349 - sparse_categorical_accuracy: 0.1500 - val_loss: 2.9151 - val_sparse_categorical_accuracy: 0.1575
# Epoch 330/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9299 - sparse_categorical_accuracy: 0.1425 - val_loss: 2.9464 - val_sparse_categorical_accuracy: 0.1750
# Epoch 331/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9208 - sparse_categorical_accuracy: 0.1475 - val_loss: 2.9190 - val_sparse_categorical_accuracy: 0.1650
# Epoch 332/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9142 - sparse_categorical_accuracy: 0.1425 - val_loss: 2.9149 - val_sparse_categorical_accuracy: 0.1525
# Epoch 333/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9404 - sparse_categorical_accuracy: 0.1475 - val_loss: 2.9138 - val_sparse_categorical_accuracy: 0.1475
# Epoch 334/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.8939 - sparse_categorical_accuracy: 0.1550 - val_loss: 2.9026 - val_sparse_categorical_accuracy: 0.1500
# Epoch 335/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.8883 - sparse_categorical_accuracy: 0.1725 - val_loss: 2.9035 - val_sparse_categorical_accuracy: 0.1300
# Epoch 336/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9044 - sparse_categorical_accuracy: 0.1250 - val_loss: 2.9069 - val_sparse_categorical_accuracy: 0.1500
# Epoch 337/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9288 - sparse_categorical_accuracy: 0.1325 - val_loss: 2.9226 - val_sparse_categorical_accuracy: 0.1475
# Epoch 338/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9396 - sparse_categorical_accuracy: 0.1500 - val_loss: 2.9477 - val_sparse_categorical_accuracy: 0.1300
# Epoch 339/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9437 - sparse_categorical_accuracy: 0.1575 - val_loss: 2.8748 - val_sparse_categorical_accuracy: 0.1850
# Epoch 340/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9092 - sparse_categorical_accuracy: 0.1625 - val_loss: 2.8771 - val_sparse_categorical_accuracy: 0.1525
# Epoch 341/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9168 - sparse_categorical_accuracy: 0.1550 - val_loss: 2.9161 - val_sparse_categorical_accuracy: 0.1575
# Epoch 342/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9179 - sparse_categorical_accuracy: 0.1300 - val_loss: 2.8795 - val_sparse_categorical_accuracy: 0.1500
# Epoch 343/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9314 - sparse_categorical_accuracy: 0.1525 - val_loss: 2.8969 - val_sparse_categorical_accuracy: 0.1425
# Epoch 344/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9167 - sparse_categorical_accuracy: 0.1475 - val_loss: 2.8889 - val_sparse_categorical_accuracy: 0.1250
# Epoch 345/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9236 - sparse_categorical_accuracy: 0.1275 - val_loss: 2.9189 - val_sparse_categorical_accuracy: 0.1550
# Epoch 346/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9443 - sparse_categorical_accuracy: 0.1250 - val_loss: 2.9214 - val_sparse_categorical_accuracy: 0.1275
# Epoch 347/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.8988 - sparse_categorical_accuracy: 0.1500 - val_loss: 2.8979 - val_sparse_categorical_accuracy: 0.1250
# Epoch 348/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.8755 - sparse_categorical_accuracy: 0.1750 - val_loss: 2.8536 - val_sparse_categorical_accuracy: 0.1850
# Epoch 349/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9328 - sparse_categorical_accuracy: 0.1500 - val_loss: 2.9514 - val_sparse_categorical_accuracy: 0.1575
# Epoch 350/10000
# 20/20 [==============================] - 189s 10s/step - loss: 2.9207 - sparse_categorical_accuracy: 0.1600 - val_loss: 2.8734 - val_sparse_categorical_accuracy: 0.1550
# Epoch 351/10000
# 20/20 [==============================] - 191s 10s/step - loss: 2.9386 - sparse_categorical_accuracy: 0.1475 - val_loss: 2.9273 - val_sparse_categorical_accuracy: 0.1425
# Epoch 352/10000
# 20/20 [==============================] - 190s 10s/step - loss: 2.9113 - sparse_categorical_accuracy: 0.1550 - val_loss: 2.9143 - val_sparse_categorical_accuracy: 0.1150
# Epoch 353/10000
# 20/20 [==============================] - ETA: 0s - loss: 2.9270 - sparse_categorical_accuracy: 0.1350

# %%
previous_history = history

# %%
model.save_weights("./Saved_Models/Str_Xl_BigBird.h5")

# %%
u = model.evaluate(dataset[3][0], dataset[3][1])

# %%
u = model.predict(dataset[0][0])

# %%
u = u.argmax(-1)

# %%
u

# %%
dataset[0][1]

# %%
random_samples[0:5]
