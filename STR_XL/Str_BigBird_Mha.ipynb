# %% [markdown]
# ---
# # Transformer XL
# ---

# %% [markdown]
# ---
# # Import Libraries

# %%
import os
import sys

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# %%
sys.path.append("../../deep-learning-dna")

# %%
import wandb

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display
import math
import string

import BigBird
import Set_Transformer 
from common.models import dnabert
from common import dna
from lmdbm import Lmdb
from common.data import DnaSequenceGenerator, DnaLabelType, DnaSampleGenerator, find_dbs
import wandb

import tf_utils as tfu

# %%
strategy = tfu.strategy.gpu(1)

# %% [markdown]
# ---
# # Load Data

# %%
#Import pretrained model
api = wandb.Api()
model_path = api.artifact("sirdavidludwig/dnabert-pretrain/dnabert-pretrain-8dim:latest").download()
pretrained_model = dnabert.DnaBertModel.load(model_path)
pretrained_model.load_weights(model_path + "/model.h5")
pretrained_model

# %%
#Load datafiles
dataset_path = api.artifact("sirdavidludwig/nachusa-dna/dnasamples-complete:latest").download('/data/dna_samples:v1')
samples = find_dbs(dataset_path + '/train')
samples[13]
# Out:
# wandb: Downloading large artifact dnasamples-complete:latest, 4079.09MB. 420 files... Done. 0:0:0.1
# '/data/dna_samples:v1/train/WS-CCW-Jul2015_S82_L001_R1_001.db'

# %% [markdown]
# ---
# # Create Dataset

# %%
split_ratios = [0.8, 0.2]
set_len = 1000
sequence_len = 150
kmer = 3
batch_size = [20,5]
batches_per_epoch = 20
augument = True
labels = DnaLabelType.SampleIds
seed = 0
rng = np.random.default_rng(seed)
random_samples = samples.copy()

# %%
rng.shuffle(random_samples)

# %%
trimmed_samples, (train_dataset, val_dataset) = DnaSampleGenerator.split(samples=random_samples[0:50], split_ratios=split_ratios, subsample_length=set_len, sequence_length=sequence_len,kmer=kmer,batch_size=batch_size,batches_per_epoch=batches_per_epoch,augment=augument,labels=labels, rng=rng)
# Out:
# Sample '/data/dna_samples:v1/train/Wes7-PCRblank1_S8_L001_R1_001.db' does not contain enough sequences. This sample will be ignored.
# Sample '/data/dna_samples:v1/train/Wes7-PCRblank1_S8_L001_R1_001.db' does not contain enough sequences. This sample will be ignored.

# %%
random_samples[0:50]
# Out:
# ['/data/dna_samples:v1/train/WS-CCE-Apr2016_S6_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes52-10-TC_S53_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-WH-Jul2016_S46_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes41-10-HN_S42_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley026-Ag-072820_S165_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-MU-Apr2016_S84_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes5-5-CCE_S6_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-MR-Apr2016_S13_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-MU-Sep2015_S43_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley012-HN-051120_S151_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-HPN-Sep2015_S91_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TCR-Sep2015_S52_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes26-8-AG_S27_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SB-Jul2016_S22_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes25-8-MU_S26_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SB-Oct2016_S63_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes3-5-TCR_S4_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-WH-May2015_S160_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TCR-Oct2016_S80_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TC-Jul2015_S74_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SB-Sep2015_S35_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-CCW-Sep2015_S28_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TC-Oct2016_S48_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-HF-Jul2015_S42_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-TCR-May2015_S73_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-HPN-Apr2016_S37_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-AG-Apr2016_S85_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes7-PCRblank1_S8_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes20-8-HF_S21_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes38-10-WH_S39_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley047-SF-100420_S186_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley055-HAP-051120_S194_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley006-HLP-051220_S145_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes39-10-HF_S40_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SF-Jul2016_S38_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley035-HLP2-072820_S174_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes13-5-HLP_S14_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-HPN-May2015_S17_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley005-HF-051220_S144_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes47-10-FC_S48_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-SF-May2015_S152_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley045-HLP-100420_S184_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley033-MU-072820_S172_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley043-L-100420_S182_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes48-10-CCW_S49_L001_R1_001.db',
#  '/data/dna_samples:v1/train/WS-AG-Sep2015_S44_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley010-HW-051120_S149_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wes36-8-HW_S37_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley011-Ag-051120_S150_L001_R1_001.db',
#  '/data/dna_samples:v1/train/Wesley027-HLP-072820_S166_L001_R1_001.db']

# %% [markdown]
# ---
# # Batch Parameters

# %%
block_size = 200
seq_len = set_len
maxlen = set_len
vocab_size = 5
num_chars_data = set_len*sequence_len
max_files = len(train_dataset.samples)
max_files
# Out:
# 49

# %%
if block_size-2 > seq_len:
    raise ValueError("Block size should not be bigger than sequence length")

# %%
print(maxlen)
print(vocab_size)
print(num_chars_data)
# Out:
# 1000
# 5
# 150000

# %% [markdown]
# ---
# # Create Embeddings

# %%
#Create 8 dimensional embeddings
pretrained_encoder = dnabert.DnaBertEncoderModel(pretrained_model.base)
pretrained_encoder.trainable = False

# %%
class Create_Embeddings(keras.layers.Layer):
    def __init__(self, encoder):
        super(Create_Embeddings, self).__init__()
        self.encoder = encoder
        
    def subbatch_predict(self, model, batch, subbatch_size, concat=lambda old, new: tf.concat((old, new), axis=0)):
        def predict(i, result=None):
            n = i + subbatch_size
            pred = tf.stop_gradient(model(batch[i:n]))
            if result is None:
                return [n, pred]
            return [n, concat(result, pred)]
        i, result = predict(0)
        batch_size = tf.shape(batch)[0]
        i, result = tf.while_loop(
            cond=lambda i, _: i < batch_size,
            body=predict,
            loop_vars=[i, result],
            parallel_iterations=1)

        return result
    
    def modify_data_for_input(self, data):
        batch_size = tf.shape(data)[0]
        subsample_size = tf.shape(data)[1]
        flat_data = tf.reshape(data, (batch_size*subsample_size, -1))
        encoded = self.subbatch_predict(self.encoder, flat_data, 128)
        return tf.reshape(encoded, (batch_size, subsample_size, -1))
    
    def call(self, data):
        return  self.modify_data_for_input(data)

# %% [markdown]
# ---
# # Setup

# %%
def clone_initializer(initializer):
    if isinstance(initializer, tf.keras.initializers.Initializer):
        return initializer.__class__.from_config(initializer.get_config())
    return initializer

# %%
mask = tf.ones(tf.shape(train_dataset[0][0])[:-1])

# %% [markdown]
# ---
# # Create Big Bird Masks

# %%
class Create_BigBird_Masks(keras.layers.Layer):
    def __init__(self, attention_block_size):
        super(Create_BigBird_Masks, self).__init__()
            
        self.mask_layer = BigBird.BigBirdMasks(block_size=attention_block_size)
        
    def call(self, one_batch):

        mask = tf.ones(tf.shape(one_batch)[:-1])
                       
        masks = self.mask_layer(one_batch, mask)      
        
        return masks

# %% [markdown]
# ---
# # Cache Memory

# %%
def _cache_memory(current_state, previous_state, memory_length, reuse_length=0):
    if memory_length is None or memory_length == 0:
        return None
    else:
        if reuse_length > 0:
            current_state = current_state[:, :reuse_length, :]

        if previous_state is None:
            new_mem = current_state[:, -memory_length:, :]
        else:
            new_mem = tf.concat(
                    [previous_state, current_state], 1)[:, -memory_length:, :]

    return tf.stop_gradient(new_mem)

# %% [markdown]
# ---
# # XL Block

# %%
class TransformerXLBlock(tf.keras.layers.Layer):
    def __init__(self,
                 vocab_size,
                 hidden_size,
                 num_attention_heads,
                 head_size,
                 inner_size,
                 dropout_rate,
                 attention_dropout_rate,
                 norm_epsilon=1e-12,
                 inner_activation="relu",
                 kernel_initializer="variance_scaling",
                 inner_dropout=0.0,
                 **kwargs):

        super(TransformerXLBlock, self).__init__(**kwargs)
        self._vocab_size = vocab_size
        self._num_heads = num_attention_heads
        self._head_size = head_size
        self._hidden_size = hidden_size
        self._inner_size = inner_size
        self._dropout_rate = dropout_rate
        self._attention_dropout_rate = attention_dropout_rate
        self._inner_activation = inner_activation
        self._norm_epsilon = norm_epsilon
        self._kernel_initializer = kernel_initializer
        self._inner_dropout = inner_dropout
        self._attention_layer_type = BigBird.BigBirdAttention
        
    def build(self, input_shape):
        input_tensor = input_shape[0] if len(input_shape) == 2 else input_shape
        input_tensor_shape = tf.TensorShape(input_tensor)
        if len(input_tensor_shape.as_list()) != 3:
            raise ValueError("TransformerLayer expects a three-dimensional input of "
                                             "shape [batch, sequence, width].")
        batch_size, sequence_length, hidden_size = input_tensor_shape

        if len(input_shape) == 2:
            mask_tensor_shape = tf.TensorShape(input_shape[1])
            expected_mask_tensor_shape = tf.TensorShape(
                    [batch_size, sequence_length, sequence_length])
            if not expected_mask_tensor_shape.is_compatible_with(mask_tensor_shape):
                raise ValueError("When passing a mask tensor to TransformerXLBlock, "
                                                 "the mask tensor must be of shape [batch, "
                                                 "sequence_length, sequence_length] (here %s). Got a "
                                                 "mask tensor of shape %s." %
                                                 (expected_mask_tensor_shape, mask_tensor_shape))
        if hidden_size % self._num_heads != 0:
            raise ValueError(
                    "The input size (%d) is not a multiple of the number of attention "
                    "heads (%d)" % (hidden_size, self._num_heads))
            

        self._attention_layer = self._attention_layer_type(num_heads=8,key_dim=32, num_rand_blocks=4,from_block_size=4,to_block_size=4,max_rand_mask_length=set_len)
        
        self._attention_dropout = tf.keras.layers.Dropout(
                rate=self._attention_dropout_rate)
        self._attention_layer_norm = tf.keras.layers.LayerNormalization(
                name="self_attention_layer_norm",
                axis=-1,
                epsilon=self._norm_epsilon,
                dtype=tf.float32)
        self._inner_dense = tf.keras.layers.experimental.EinsumDense(
                "abc,cd->abd",
                output_shape=(None, self._inner_size),
                bias_axes="d",
                kernel_initializer=clone_initializer(self._kernel_initializer),
                name="inner")

        self._inner_activation_layer = tf.keras.layers.Activation(
                self._inner_activation)
        self._inner_dropout_layer = tf.keras.layers.Dropout(
                rate=self._inner_dropout)
        self._output_dense = tf.keras.layers.experimental.EinsumDense(
                "abc,cd->abd",
                output_shape=(None, hidden_size),
                bias_axes="d",
                name="output",
                kernel_initializer=clone_initializer(self._kernel_initializer))
        self._output_dropout = tf.keras.layers.Dropout(rate=self._dropout_rate)
        self._output_layer_norm = tf.keras.layers.LayerNormalization(
                name="output_layer_norm",
                axis=-1,
                epsilon=self._norm_epsilon)

        super(TransformerXLBlock, self).build(input_shape)

    def call(self,
             content_stream,
             mask = None,
             relative_position_encoding=None,
             state=None,
             content_attention_mask=None,
             query_attention_mask=None,
             target_mapping=None):
        
        attention_kwargs = dict(
                query=content_stream,
                value=content_stream,
                key=content_stream,
                state = None,
                attention_mask=mask)

        attention_output = self._attention_layer(**attention_kwargs)
        
        attention_stream = attention_output
        input_stream = content_stream
        attention_key = "content_attention"
        attention_output = {}
        
        attention_stream = self._attention_dropout(attention_stream)
        attention_stream = self._attention_layer_norm(attention_stream + input_stream)
        inner_output = self._inner_dense(attention_stream)
        inner_output = self._inner_activation_layer(
                inner_output)
        inner_output = self._inner_dropout_layer(
                inner_output)
        layer_output = self._output_dense(inner_output)
        layer_output = self._output_dropout(layer_output)
        layer_output = self._output_layer_norm(layer_output + attention_stream)
        attention_output[attention_key] = layer_output

        return attention_output

# %% [markdown]
# ---
# # Transformer XL

# %%
class TransformerXL(tf.keras.layers.Layer):
    def __init__(self,
                 vocab_size,
                 num_layers,
                 hidden_size,
                 maxlen,
                 embed_dim,
                 num_attention_heads,
                 head_size,
                 inner_size,
                 dropout_rate,
                 attention_dropout_rate,
                 initializer,
                 tie_attention_biases=True,
                 memory_length=None,
                 reuse_length=None,
                 inner_activation="relu",
                 **kwargs):
        super(TransformerXL, self).__init__(**kwargs)

        self._vocab_size = vocab_size
        self._initializer = initializer
        self._num_layers = num_layers
        self._hidden_size = hidden_size
        self._num_attention_heads = num_attention_heads
        self._head_size = head_size
        self._inner_size = inner_size
        self._inner_activation = inner_activation
        self._dropout_rate = dropout_rate
        self._attention_dropout_rate = attention_dropout_rate
        self._tie_attention_biases = tie_attention_biases

        self._memory_length = memory_length
        self._reuse_length = reuse_length

        if self._tie_attention_biases:
            attention_bias_shape = [self._num_attention_heads, self._head_size]
        else:
            attention_bias_shape = [self._num_layers, self._num_attention_heads, self._head_size]

        self.transformer_xl_layers = []
        
        for i in range(self._num_layers):
            self.transformer_xl_layers.append(
                    TransformerXLBlock(
                            vocab_size=self._vocab_size,
                            hidden_size=self._head_size * self._num_attention_heads,
                            num_attention_heads=self._num_attention_heads,
                            head_size=self._head_size,
                            inner_size=self._inner_size,
                            dropout_rate=self._dropout_rate,
                            attention_dropout_rate=self._attention_dropout_rate,
                            norm_epsilon=1e-12,
                            inner_activation=self._inner_activation,
                            kernel_initializer="variance_scaling",
                            name="layer_%d" % i))

        self.output_dropout = tf.keras.layers.Dropout(rate=self._dropout_rate)


    def call(self,
             content_stream,
             relative_position_encoding,
             mask, 
             state=None,
             content_attention_mask=None,
             query_attention_mask=None,
             target_mapping=None):
        
        new_mems = []

        if state is None:
            state = [None] * self._num_layers
        for i in range(self._num_layers):
            # cache new mems
            new_mems.append(_cache_memory(content_stream, state[i], self._memory_length, self._reuse_length))

            transformer_xl_layer = self.transformer_xl_layers[i]
            
            transformer_xl_output = transformer_xl_layer(
                    content_stream=content_stream,
                    mask=mask,
                    relative_position_encoding=relative_position_encoding,
                    state=state[i],
                    content_attention_mask=content_attention_mask,
                    query_attention_mask=query_attention_mask,
                    target_mapping=target_mapping)
            content_stream = transformer_xl_output["content_attention"]

        output_stream = content_stream
        return output_stream, new_mems

# %% [markdown]
# ---
# # Xl Model Class

# %%
class XlModel(keras.Model):
    def __init__(self, attention_block_size, max_files, encoder, block_size, seq_len_padded, embed_dim, vocab_size, num_layers, hidden_size, num_attention_heads, maxlen, memory_length, reuse_length, head_size, inner_size, dropout_rate, attention_dropout_rate, initializer):
        super(XlModel, self).__init__()
        
        self.block_size = block_size
        self.seq_len_padded = seq_len_padded
        self.embed_dim = embed_dim
        self.num_heads = num_attention_heads
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.maxlen = maxlen
        self.memory_length = memory_length
        self.max_files = max_files
        self.encoder = encoder
        self.isabs = []
        
        self.mask_layer = Create_BigBird_Masks(attention_block_size)
            
        self.embedding_layer = Create_Embeddings(encoder)

        self.linear_layer = keras.layers.Dense(self.embed_dim)
        
        self.transformer_xl = TransformerXL(
                vocab_size=vocab_size,
                num_layers=num_layers,
                hidden_size=hidden_size,
                num_attention_heads=num_attention_heads,
                maxlen=maxlen,
                embed_dim=embed_dim,
                memory_length=memory_length,
                reuse_length=reuse_length,
                head_size=head_size,
                inner_size=inner_size,
                dropout_rate=dropout_rate,
                attention_dropout_rate=attention_dropout_rate,
                initializer=initializer, 
            )
        

        self.pooling_layer = Set_Transformer.PoolingByMultiHeadAttention(num_seeds=1,embed_dim=embed_dim,num_heads=1,use_layernorm=True,pre_layernorm=True, use_keras_mha=True,is_final_block=True)
    
        self.reshape_layer = keras.layers.Reshape((embed_dim,))
   
        self.output_layer = keras.layers.Dense(self.max_files, activation=keras.activations.softmax)
        
    
    def call(self, x, training=None):        

        #mems = tf.zeros((self.num_layers, tf.shape(x)[0], self.memory_length, self.embed_dim))
        
        embeddings = self.embedding_layer(x)
            
        linear_transform = self.linear_layer(embeddings)    
        
#         for i in range(0, self.seq_len_padded, self.block_size):
            
#             block = embeddings[:,i:i+self.block_size]
            
#             mask = self.mask_layer(block)
            
#             output, mems = self.transformer_xl(content_stream=block, mask=mask, relative_position_encoding=None, state=None)

            
        mask = self.mask_layer(embeddings)

        output, mems = self.transformer_xl(content_stream=embeddings, mask=mask, relative_position_encoding=None, state=None)
                
        pooling = self.pooling_layer(output)

        reshape = self.reshape_layer(pooling)

        output = self.output_layer(reshape)          
        
        return output

# %% [markdown]
# ---
# # Attention Parameters

# %%
attention_block_size = 4

# %% [markdown]
# ---
# # Xl Parameters

# %%
#Xl Parameters 
embed_dim = 8
num_layers = 10
hidden_size = 64
num_attention_heads = 8
memory_length = 200
reuse_length = 0
head_size = 8
inner_size = 64
dropout_rate = 0.01
attention_dropout_rate = 0.01
initializer = keras.initializers.RandomNormal(stddev=0.1) 

encoder = pretrained_encoder
epochs = 10000

# %%
Parameters = dict(
    embed_dim = 8,
    num_layers = 10,
    hidden_size = 64,
    num_attention_heads = 8,
    memory_length = 200,
    reuse_length = 0,
    head_size = 8,
    inner_size = 64,
    dropout_rate = 0.01,
    attention_dropout_rate = 0.01,
    set_len=set_len)

# %%
run = wandb.init(project="Str_BigBird_Mha", config=Parameters)
# Out:
# Finishing last run (ID:2e9c2397) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">honest-violet-12</strong>: <a href="https://wandb.ai/kendragivens/Str_BigBird_Mha/runs/2e9c2397" target="_blank">https://wandb.ai/kendragivens/Str_BigBird_Mha/runs/2e9c2397</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220725_193150-2e9c2397/logs</code>
# Successfully finished last run (ID:2e9c2397). Initializing new run:<br/>
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/home/jovyan/work/TransformerXL/STR_XL/wandb/run-20220725_193301-1ywz1mgf</code>
# Syncing run <strong><a href="https://wandb.ai/kendragivens/Str_BigBird_Mha/runs/1ywz1mgf" target="_blank">cool-lake-13</a></strong> to <a href="https://wandb.ai/kendragivens/Str_BigBird_Mha" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# ---
# # Create Models

# %%
model = XlModel(attention_block_size, max_files, encoder, block_size, seq_len, embed_dim, vocab_size, num_layers, hidden_size, num_attention_heads, maxlen, memory_length, reuse_length, head_size, inner_size, dropout_rate, attention_dropout_rate, initializer)
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False), optimizer = keras.optimizers.Adam(1e-3), metrics = keras.metrics.SparseCategoricalAccuracy())

# %%
history = model.fit(x=train_dataset, validation_data=val_dataset, epochs=epochs, verbose=1, callbacks=[wandb.keras.WandbCallback(save_weights_only=True)])
# Out:
# wandb: WARNING Unable to compute FLOPs for this model.
# Epoch 1/10000
# WARNING:tensorflow:Gradients do not exist for variables ['xl_model_3/dense_29/kernel:0', 'xl_model_3/dense_29/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['xl_model_3/dense_29/kernel:0', 'xl_model_3/dense_29/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 20/20 [==============================] - 146s 6s/step - loss: 4.0447 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.9591 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658795741.0000 - _runtime: 156.0000
# Epoch 2/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.9526 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.9284 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658795861.0000 - _runtime: 276.0000
# Epoch 3/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.8472 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.7886 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658795981.0000 - _runtime: 396.0000
# Epoch 4/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.7877 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.7270 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658796102.0000 - _runtime: 517.0000
# Epoch 5/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.7155 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.6608 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658796222.0000 - _runtime: 637.0000
# Epoch 6/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.6643 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.5935 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658796342.0000 - _runtime: 757.0000
# Epoch 7/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.6481 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.6047 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658796462.0000 - _runtime: 877.0000
# Epoch 8/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.5532 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.5613 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658796582.0000 - _runtime: 997.0000
# Epoch 9/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.5616 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.5149 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658796703.0000 - _runtime: 1118.0000
# Epoch 10/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.5153 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.5046 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658796823.0000 - _runtime: 1238.0000
# Epoch 11/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.4957 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.5404 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658796943.0000 - _runtime: 1358.0000
# Epoch 12/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.4778 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.4297 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658797063.0000 - _runtime: 1478.0000
# Epoch 13/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.4341 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.4519 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658797183.0000 - _runtime: 1598.0000
# Epoch 14/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.4374 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.4461 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658797303.0000 - _runtime: 1718.0000
# Epoch 15/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.4128 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.4016 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658797423.0000 - _runtime: 1838.0000
# Epoch 16/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3882 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.4065 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658797544.0000 - _runtime: 1959.0000
# Epoch 17/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3923 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.3614 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658797664.0000 - _runtime: 2079.0000
# Epoch 18/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3718 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.3670 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658797784.0000 - _runtime: 2199.0000
# Epoch 19/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3607 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.3896 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658797904.0000 - _runtime: 2319.0000
# Epoch 20/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3511 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.3630 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658798024.0000 - _runtime: 2439.0000
# Epoch 21/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3458 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.3447 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658798144.0000 - _runtime: 2559.0000
# Epoch 22/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3326 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.3377 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658798264.0000 - _runtime: 2679.0000
# Epoch 23/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3281 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.3291 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658798384.0000 - _runtime: 2799.0000
# Epoch 24/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3291 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.3141 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658798505.0000 - _runtime: 2920.0000
# Epoch 25/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3366 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.3226 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658798625.0000 - _runtime: 3040.0000
# Epoch 26/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3103 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.3018 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658798745.0000 - _runtime: 3160.0000
# Epoch 27/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3030 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2985 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658798865.0000 - _runtime: 3280.0000
# Epoch 28/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3085 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.3008 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658798985.0000 - _runtime: 3400.0000
# Epoch 29/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3043 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2838 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658799105.0000 - _runtime: 3520.0000
# Epoch 30/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2947 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.3115 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658799226.0000 - _runtime: 3641.0000
# Epoch 31/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3091 - sparse_categorical_accuracy: 0.0175 - val_loss: 3.2997 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658799346.0000 - _runtime: 3761.0000
# Epoch 32/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.3040 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2773 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658799466.0000 - _runtime: 3881.0000
# Epoch 33/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2877 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2893 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658799586.0000 - _runtime: 4001.0000
# Epoch 34/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2921 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2974 - val_sparse_categorical_accuracy: 0.0000e+00 - _timestamp: 1658799706.0000 - _runtime: 4121.0000
# Epoch 35/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2837 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2949 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658799826.0000 - _runtime: 4241.0000
# Epoch 36/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2961 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2818 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658799945.0000 - _runtime: 4360.0000
# Epoch 37/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2760 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2882 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658800065.0000 - _runtime: 4480.0000
# Epoch 38/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2829 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2778 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658800185.0000 - _runtime: 4600.0000
# Epoch 39/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2861 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2945 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658800305.0000 - _runtime: 4720.0000
# Epoch 40/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2724 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2622 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658800425.0000 - _runtime: 4840.0000
# Epoch 41/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2674 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2607 - val_sparse_categorical_accuracy: 0.0900 - _timestamp: 1658800546.0000 - _runtime: 4961.0000
# Epoch 42/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2695 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2834 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658800666.0000 - _runtime: 5081.0000
# Epoch 43/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2729 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2663 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658800786.0000 - _runtime: 5201.0000
# Epoch 44/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2717 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2709 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658800906.0000 - _runtime: 5321.0000
# Epoch 45/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2728 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.2791 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658801026.0000 - _runtime: 5441.0000
# Epoch 46/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2648 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2697 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658801146.0000 - _runtime: 5561.0000
# Epoch 47/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2748 - sparse_categorical_accuracy: 0.0225 - val_loss: 3.2562 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658801266.0000 - _runtime: 5681.0000
# Epoch 48/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2587 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2561 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658801386.0000 - _runtime: 5801.0000
# Epoch 49/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2586 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2472 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658801506.0000 - _runtime: 5921.0000
# Epoch 50/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2570 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2629 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658801626.0000 - _runtime: 6041.0000
# Epoch 51/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2586 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2483 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658801746.0000 - _runtime: 6161.0000
# Epoch 52/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2466 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2430 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658801866.0000 - _runtime: 6281.0000
# Epoch 53/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2669 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.2559 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658801987.0000 - _runtime: 6402.0000
# Epoch 54/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2576 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2516 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658802106.0000 - _runtime: 6521.0000
# Epoch 55/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2534 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2394 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658802226.0000 - _runtime: 6641.0000
# Epoch 56/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2546 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2689 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658802347.0000 - _runtime: 6762.0000
# Epoch 57/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2518 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.2620 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658802467.0000 - _runtime: 6882.0000
# Epoch 58/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2503 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2697 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658802587.0000 - _runtime: 7002.0000
# Epoch 59/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2521 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2634 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658802706.0000 - _runtime: 7121.0000
# Epoch 60/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2499 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2362 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658802826.0000 - _runtime: 7241.0000
# Epoch 61/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2594 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2519 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658802947.0000 - _runtime: 7362.0000
# Epoch 62/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2413 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2411 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658803067.0000 - _runtime: 7482.0000
# Epoch 63/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2612 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2485 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658803187.0000 - _runtime: 7602.0000
# Epoch 64/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2430 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2431 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658803307.0000 - _runtime: 7722.0000
# Epoch 65/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2397 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2383 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658803426.0000 - _runtime: 7841.0000
# Epoch 66/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2420 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2265 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658803546.0000 - _runtime: 7961.0000
# Epoch 67/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2582 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2509 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658803667.0000 - _runtime: 8082.0000
# Epoch 68/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2484 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2448 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658803787.0000 - _runtime: 8202.0000
# Epoch 69/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2486 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2562 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658803906.0000 - _runtime: 8321.0000
# Epoch 70/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2454 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2540 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658804026.0000 - _runtime: 8441.0000
# Epoch 71/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2398 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2304 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658804147.0000 - _runtime: 8562.0000
# Epoch 72/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2526 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2252 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658804266.0000 - _runtime: 8681.0000
# Epoch 73/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2457 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2593 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658804387.0000 - _runtime: 8802.0000
# Epoch 74/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2440 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2284 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658804507.0000 - _runtime: 8922.0000
# Epoch 75/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2365 - sparse_categorical_accuracy: 0.0225 - val_loss: 3.2398 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658804627.0000 - _runtime: 9042.0000
# Epoch 76/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2459 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2258 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658804747.0000 - _runtime: 9162.0000
# Epoch 77/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2460 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2414 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658804866.0000 - _runtime: 9281.0000
# Epoch 78/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2364 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2449 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658804986.0000 - _runtime: 9401.0000
# Epoch 79/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2394 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2319 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658805106.0000 - _runtime: 9521.0000
# Epoch 80/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2381 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.2428 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658805226.0000 - _runtime: 9641.0000
# Epoch 81/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2325 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2129 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658805346.0000 - _runtime: 9761.0000
# Epoch 82/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2383 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2605 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658805466.0000 - _runtime: 9881.0000
# Epoch 83/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2472 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2326 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658805586.0000 - _runtime: 10001.0000
# Epoch 84/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2311 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2252 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658805706.0000 - _runtime: 10121.0000
# Epoch 85/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2297 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2515 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658805826.0000 - _runtime: 10241.0000
# Epoch 86/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2344 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2313 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658805946.0000 - _runtime: 10361.0000
# Epoch 87/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2436 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2494 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658806066.0000 - _runtime: 10481.0000
# Epoch 88/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2309 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2500 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658806186.0000 - _runtime: 10601.0000
# Epoch 89/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2360 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2367 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658806306.0000 - _runtime: 10721.0000
# Epoch 90/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2331 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.2271 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658806426.0000 - _runtime: 10841.0000
# Epoch 91/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2289 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2397 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658806546.0000 - _runtime: 10961.0000
# Epoch 92/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2363 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2340 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658806666.0000 - _runtime: 11081.0000
# Epoch 93/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2308 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2320 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658806786.0000 - _runtime: 11201.0000
# Epoch 94/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2266 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2375 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658806906.0000 - _runtime: 11321.0000
# Epoch 95/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2406 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2370 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658807026.0000 - _runtime: 11441.0000
# Epoch 96/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2187 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.2120 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658807146.0000 - _runtime: 11561.0000
# Epoch 97/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2483 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2299 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658807267.0000 - _runtime: 11682.0000
# Epoch 98/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2310 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2216 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658807387.0000 - _runtime: 11802.0000
# Epoch 99/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2405 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.2184 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658807507.0000 - _runtime: 11922.0000
# Epoch 100/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2333 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2511 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658807627.0000 - _runtime: 12042.0000
# Epoch 101/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2293 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2237 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658807747.0000 - _runtime: 12162.0000
# Epoch 102/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2338 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2250 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658807867.0000 - _runtime: 12282.0000
# Epoch 103/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2287 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2373 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658807987.0000 - _runtime: 12402.0000
# Epoch 104/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2327 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2424 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658808107.0000 - _runtime: 12522.0000
# Epoch 105/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2287 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2256 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658808227.0000 - _runtime: 12642.0000
# Epoch 106/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2258 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.2400 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658808347.0000 - _runtime: 12762.0000
# Epoch 107/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2356 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2108 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658808467.0000 - _runtime: 12882.0000
# Epoch 108/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2291 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2392 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658808587.0000 - _runtime: 13002.0000
# Epoch 109/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2341 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2416 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658808707.0000 - _runtime: 13122.0000
# Epoch 110/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2257 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2160 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658808827.0000 - _runtime: 13242.0000
# Epoch 111/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2413 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2217 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658808947.0000 - _runtime: 13362.0000
# Epoch 112/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2281 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2392 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658809067.0000 - _runtime: 13482.0000
# Epoch 113/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2269 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2296 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658809187.0000 - _runtime: 13602.0000
# Epoch 114/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2254 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2104 - val_sparse_categorical_accuracy: 0.1100 - _timestamp: 1658809307.0000 - _runtime: 13722.0000
# Epoch 115/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2258 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2269 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658809427.0000 - _runtime: 13842.0000
# Epoch 116/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2389 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.2346 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658809547.0000 - _runtime: 13962.0000
# Epoch 117/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2197 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2417 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658809667.0000 - _runtime: 14082.0000
# Epoch 118/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2191 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2398 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658809787.0000 - _runtime: 14202.0000
# Epoch 119/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2275 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2662 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658809908.0000 - _runtime: 14323.0000
# Epoch 120/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2259 - sparse_categorical_accuracy: 0.0175 - val_loss: 3.2535 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658810027.0000 - _runtime: 14442.0000
# Epoch 121/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2295 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2229 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658810147.0000 - _runtime: 14562.0000
# Epoch 122/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2366 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2314 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658810267.0000 - _runtime: 14682.0000
# Epoch 123/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2309 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2213 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658810387.0000 - _runtime: 14802.0000
# Epoch 124/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2286 - sparse_categorical_accuracy: 0.0225 - val_loss: 3.2163 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658810507.0000 - _runtime: 14922.0000
# Epoch 125/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2268 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2334 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658810627.0000 - _runtime: 15042.0000
# Epoch 126/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2269 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2208 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658810747.0000 - _runtime: 15162.0000
# Epoch 127/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2323 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2191 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658810867.0000 - _runtime: 15282.0000
# Epoch 128/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2259 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.2117 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658810987.0000 - _runtime: 15402.0000
# Epoch 129/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2099 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2234 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658811107.0000 - _runtime: 15522.0000
# Epoch 130/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2204 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2037 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658811227.0000 - _runtime: 15642.0000
# Epoch 131/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2202 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2349 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658811348.0000 - _runtime: 15763.0000
# Epoch 132/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2270 - sparse_categorical_accuracy: 0.0200 - val_loss: 3.2252 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658811467.0000 - _runtime: 15882.0000
# Epoch 133/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2257 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2182 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658811587.0000 - _runtime: 16002.0000
# Epoch 134/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2226 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2105 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658811707.0000 - _runtime: 16122.0000
# Epoch 135/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2204 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2345 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658811827.0000 - _runtime: 16242.0000
# Epoch 136/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2268 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2099 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658811947.0000 - _runtime: 16362.0000
# Epoch 137/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2173 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2174 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658812067.0000 - _runtime: 16482.0000
# Epoch 138/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2313 - sparse_categorical_accuracy: 0.0225 - val_loss: 3.2279 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658812187.0000 - _runtime: 16602.0000
# Epoch 139/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2250 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2194 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658812307.0000 - _runtime: 16722.0000
# Epoch 140/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2262 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2437 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658812427.0000 - _runtime: 16842.0000
# Epoch 141/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2242 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2274 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658812547.0000 - _runtime: 16962.0000
# Epoch 142/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2242 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2045 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658812667.0000 - _runtime: 17082.0000
# Epoch 143/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2233 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2391 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658812787.0000 - _runtime: 17202.0000
# Epoch 144/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2316 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2176 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658812907.0000 - _runtime: 17322.0000
# Epoch 145/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2244 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.2264 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658813027.0000 - _runtime: 17442.0000
# Epoch 146/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2276 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2337 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658813147.0000 - _runtime: 17562.0000
# Epoch 147/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2226 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.2262 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658813267.0000 - _runtime: 17682.0000
# Epoch 148/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2392 - sparse_categorical_accuracy: 0.0200 - val_loss: 3.2200 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658813387.0000 - _runtime: 17802.0000
# Epoch 149/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2200 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2176 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658813507.0000 - _runtime: 17922.0000
# Epoch 150/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2170 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2292 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658813627.0000 - _runtime: 18042.0000
# Epoch 151/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2178 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2192 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658813747.0000 - _runtime: 18162.0000
# Epoch 152/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2218 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2218 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658813867.0000 - _runtime: 18282.0000
# Epoch 153/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2168 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2156 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658813987.0000 - _runtime: 18402.0000
# Epoch 154/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2289 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2067 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658814107.0000 - _runtime: 18522.0000
# Epoch 155/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2208 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2283 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658814227.0000 - _runtime: 18642.0000
# Epoch 156/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2190 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2147 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658814347.0000 - _runtime: 18762.0000
# Epoch 157/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2162 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2311 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658814467.0000 - _runtime: 18882.0000
# Epoch 158/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2199 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2166 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658814587.0000 - _runtime: 19002.0000
# Epoch 159/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2263 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2316 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658814707.0000 - _runtime: 19122.0000
# Epoch 160/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2208 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.2182 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658814827.0000 - _runtime: 19242.0000
# Epoch 161/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2236 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2098 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658814947.0000 - _runtime: 19362.0000
# Epoch 162/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2163 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2201 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658815067.0000 - _runtime: 19482.0000
# Epoch 163/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2192 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2132 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658815187.0000 - _runtime: 19602.0000
# Epoch 164/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2210 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2220 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658815307.0000 - _runtime: 19722.0000
# Epoch 165/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2236 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.1972 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658815427.0000 - _runtime: 19842.0000
# Epoch 166/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2251 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2184 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658815548.0000 - _runtime: 19963.0000
# Epoch 167/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2098 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2211 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658815668.0000 - _runtime: 20083.0000
# Epoch 168/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2301 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.1994 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658815788.0000 - _runtime: 20203.0000
# Epoch 169/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2272 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2236 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658815908.0000 - _runtime: 20323.0000
# Epoch 170/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2236 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2304 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658816028.0000 - _runtime: 20443.0000
# Epoch 171/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2069 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2066 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658816148.0000 - _runtime: 20563.0000
# Epoch 172/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2102 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2436 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658816268.0000 - _runtime: 20683.0000
# Epoch 173/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2132 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2130 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658816388.0000 - _runtime: 20803.0000
# Epoch 174/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2263 - sparse_categorical_accuracy: 0.0200 - val_loss: 3.2048 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658816508.0000 - _runtime: 20923.0000
# Epoch 175/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2175 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2244 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658816628.0000 - _runtime: 21043.0000
# Epoch 176/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2152 - sparse_categorical_accuracy: 0.0625 - val_loss: 3.2306 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658816748.0000 - _runtime: 21163.0000
# Epoch 177/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2142 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2070 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658816868.0000 - _runtime: 21283.0000
# Epoch 178/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2186 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2022 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658816988.0000 - _runtime: 21403.0000
# Epoch 179/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2198 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2113 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658817108.0000 - _runtime: 21523.0000
# Epoch 180/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2062 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.2239 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658817228.0000 - _runtime: 21643.0000
# Epoch 181/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2140 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2051 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658817348.0000 - _runtime: 21763.0000
# Epoch 182/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2289 - sparse_categorical_accuracy: 0.0225 - val_loss: 3.1996 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658817468.0000 - _runtime: 21883.0000
# Epoch 183/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2171 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2269 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658817588.0000 - _runtime: 22003.0000
# Epoch 184/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2221 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2250 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658817708.0000 - _runtime: 22123.0000
# Epoch 185/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2159 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2230 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658817828.0000 - _runtime: 22243.0000
# Epoch 186/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2079 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2191 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658817948.0000 - _runtime: 22363.0000
# Epoch 187/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2108 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2146 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658818068.0000 - _runtime: 22483.0000
# Epoch 188/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2098 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2185 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658818188.0000 - _runtime: 22603.0000
# Epoch 189/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2114 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.2094 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658818307.0000 - _runtime: 22722.0000
# Epoch 190/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2203 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2115 - val_sparse_categorical_accuracy: 0.0800 - _timestamp: 1658818427.0000 - _runtime: 22842.0000
# Epoch 191/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2255 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2141 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658818547.0000 - _runtime: 22962.0000
# Epoch 192/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2306 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2136 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658818667.0000 - _runtime: 23082.0000
# Epoch 193/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2180 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2047 - val_sparse_categorical_accuracy: 0.0000e+00 - _timestamp: 1658818787.0000 - _runtime: 23202.0000
# Epoch 194/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2067 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2317 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658818907.0000 - _runtime: 23322.0000
# Epoch 195/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2205 - sparse_categorical_accuracy: 0.0225 - val_loss: 3.2161 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658819028.0000 - _runtime: 23443.0000
# Epoch 196/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2196 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2223 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658819147.0000 - _runtime: 23562.0000
# Epoch 197/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2160 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2177 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658819267.0000 - _runtime: 23682.0000
# Epoch 198/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2194 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2191 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658819387.0000 - _runtime: 23802.0000
# Epoch 199/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2164 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.2160 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658819507.0000 - _runtime: 23922.0000
# Epoch 200/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2187 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2102 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658819627.0000 - _runtime: 24042.0000
# Epoch 201/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2102 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.2162 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658819747.0000 - _runtime: 24162.0000
# Epoch 202/10000
# ...
# Epoch 491/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2182 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2032 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658854546.0000 - _runtime: 58961.0000
# Epoch 492/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2075 - sparse_categorical_accuracy: 0.0475 - val_loss: 3.2061 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658854666.0000 - _runtime: 59081.0000
# Epoch 493/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2121 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2282 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658854786.0000 - _runtime: 59201.0000
# Epoch 494/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.1999 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2068 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658854906.0000 - _runtime: 59321.0000
# Epoch 495/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2183 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.1982 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658855026.0000 - _runtime: 59441.0000
# Epoch 496/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2155 - sparse_categorical_accuracy: 0.0600 - val_loss: 3.2055 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658855146.0000 - _runtime: 59561.0000
# Epoch 497/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2143 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.1998 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658855266.0000 - _runtime: 59681.0000
# Epoch 498/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2075 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2133 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658855386.0000 - _runtime: 59801.0000
# Epoch 499/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2033 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2029 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658855506.0000 - _runtime: 59921.0000
# Epoch 500/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2044 - sparse_categorical_accuracy: 0.0550 - val_loss: 3.2150 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658855626.0000 - _runtime: 60041.0000
# Epoch 501/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2038 - sparse_categorical_accuracy: 0.0525 - val_loss: 3.2160 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658855746.0000 - _runtime: 60161.0000
# Epoch 502/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2006 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2131 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658855866.0000 - _runtime: 60281.0000
# Epoch 503/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2111 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2188 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658855986.0000 - _runtime: 60401.0000
# Epoch 504/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2119 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.2015 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658856106.0000 - _runtime: 60521.0000
# Epoch 505/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2205 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2111 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658856226.0000 - _runtime: 60641.0000
# Epoch 506/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2030 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2069 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658856345.0000 - _runtime: 60760.0000
# Epoch 507/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2118 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.2221 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658856465.0000 - _runtime: 60880.0000
# Epoch 508/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.1978 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2244 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658856585.0000 - _runtime: 61000.0000
# Epoch 509/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2100 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2259 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658856705.0000 - _runtime: 61120.0000
# Epoch 510/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2084 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.2251 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658856825.0000 - _runtime: 61240.0000
# Epoch 511/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2108 - sparse_categorical_accuracy: 0.0300 - val_loss: 3.2202 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658856945.0000 - _runtime: 61360.0000
# Epoch 512/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2179 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.1951 - val_sparse_categorical_accuracy: 0.0100 - _timestamp: 1658857065.0000 - _runtime: 61480.0000
# Epoch 513/10000
#  2/20 [==>...........................] - ETA: 1:27 - loss: 3.1889 - sparse_categorical_accuracy: 0.0750
# wandb: Network error (ReadTimeout), entering retry loop.
# 20/20 [==============================] - 120s 6s/step - loss: 3.2160 - sparse_categorical_accuracy: 0.0575 - val_loss: 3.2021 - val_sparse_categorical_accuracy: 0.1000 - _timestamp: 1658857185.0000 - _runtime: 61600.0000
# Epoch 514/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.1998 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.1750 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658857305.0000 - _runtime: 61720.0000
# Epoch 515/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2068 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2132 - val_sparse_categorical_accuracy: 0.0200 - _timestamp: 1658857425.0000 - _runtime: 61840.0000
# Epoch 516/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2059 - sparse_categorical_accuracy: 0.0350 - val_loss: 3.1836 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658857545.0000 - _runtime: 61960.0000
# Epoch 517/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2042 - sparse_categorical_accuracy: 0.0450 - val_loss: 3.1957 - val_sparse_categorical_accuracy: 0.0700 - _timestamp: 1658857665.0000 - _runtime: 62080.0000
# Epoch 518/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2079 - sparse_categorical_accuracy: 0.0500 - val_loss: 3.2094 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658857784.0000 - _runtime: 62199.0000
# Epoch 519/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2012 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2139 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658857904.0000 - _runtime: 62319.0000
# Epoch 520/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2138 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.1943 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658858024.0000 - _runtime: 62439.0000
# Epoch 521/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2033 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2276 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658858144.0000 - _runtime: 62559.0000
# Epoch 522/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.1993 - sparse_categorical_accuracy: 0.0650 - val_loss: 3.2094 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658858264.0000 - _runtime: 62679.0000
# Epoch 523/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2131 - sparse_categorical_accuracy: 0.0325 - val_loss: 3.2043 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658858384.0000 - _runtime: 62799.0000
# Epoch 524/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2071 - sparse_categorical_accuracy: 0.0400 - val_loss: 3.2099 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658858504.0000 - _runtime: 62919.0000
# Epoch 525/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2120 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2029 - val_sparse_categorical_accuracy: 0.0400 - _timestamp: 1658858624.0000 - _runtime: 63039.0000
# Epoch 526/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2054 - sparse_categorical_accuracy: 0.0375 - val_loss: 3.2051 - val_sparse_categorical_accuracy: 0.0300 - _timestamp: 1658858744.0000 - _runtime: 63159.0000
# Epoch 527/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2041 - sparse_categorical_accuracy: 0.0275 - val_loss: 3.1876 - val_sparse_categorical_accuracy: 0.0600 - _timestamp: 1658858864.0000 - _runtime: 63279.0000
# Epoch 528/10000
# 20/20 [==============================] - 120s 6s/step - loss: 3.2152 - sparse_categorical_accuracy: 0.0425 - val_loss: 3.2074 - val_sparse_categorical_accuracy: 0.0500 - _timestamp: 1658858984.0000 - _runtime: 63399.0000
# Epoch 529/10000
# 20/20 [==============================] - ETA: 0s - loss: 3.2125 - sparse_categorical_accuracy: 0.0325
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 history = model.fit(x=train_dataset, validation_data=val_dataset, epochs=epochs, verbose=1, callbacks=[wandb.keras.WandbCallback(save_weights_only=True)])
#
# File ~/.local/lib/python3.10/site-packages/wandb/integration/keras/keras.py:173, in patch_tf_keras.<locals>.new_v2(*args, **kwargs)
#     171     for cbk in cbks:
#     172         set_wandb_attrs(cbk, val_data)
# --> 173 return old_v2(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/training.py:1420, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1406 if getattr(self, '_eval_data_handler', None) is None:
#    1407   self._eval_data_handler = data_adapter.get_data_handler(
#    1408       x=val_x,
#    1409       y=val_y,
#    (...)
#    1418       model=self,
#    1419       steps_per_execution=self._steps_per_execution)
# -> 1420 val_logs = self.evaluate(
#    1421     x=val_x,
#    1422     y=val_y,
#    1423     sample_weight=val_sample_weight,
#    1424     batch_size=validation_batch_size or batch_size,
#    1425     steps=validation_steps,
#    1426     callbacks=callbacks,
#    1427     max_queue_size=max_queue_size,
#    1428     workers=workers,
#    1429     use_multiprocessing=use_multiprocessing,
#    1430     return_dict=True,
#    1431     _use_cached_eval_dataset=True)
#    1432 val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1433 epoch_logs.update(val_logs)
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/training.py:1716, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1714 with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1715   callbacks.on_test_batch_begin(step)
# -> 1716   tmp_logs = self.test_function(iterator)
#    1717   if data_handler.should_sync:
#    1718     context.async_wait()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.004 MB of 1.004 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▃▂▂▂▂▁▂▁▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▅▄▃▂▃▃▅▇▆▂▃▄▂█▃▃▅▇▃▂▂▂▄▆▃▃▂▅▃▅▅▁▃▄▄▅▇█▃▅</td></tr><tr><td>val_loss</td><td>█▅▃▂▃▂▂▂▂▂▂▂▁▂▂▁▂▂▂▂▂▂▁▁▂▂▂▁▂▂▂▂▁▂▁▂▁▁▁▁</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▃▂▃▃▃▃▄▅▄▁▆▂▂▃▃█▂▃▄▂▃▃▅▅▅▃▆▄▃▅▃▃▄▃▁▅▃▂▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>334</td></tr><tr><td>best_val_loss</td><td>3.17426</td></tr><tr><td>epoch</td><td>527</td></tr><tr><td>loss</td><td>3.21524</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.0425</td></tr><tr><td>val_loss</td><td>3.20744</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">cool-lake-13</strong>: <a href="https://wandb.ai/kendragivens/Str_BigBird_Mha/runs/1ywz1mgf" target="_blank">https://wandb.ai/kendragivens/Str_BigBird_Mha/runs/1ywz1mgf</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220725_193301-1ywz1mgf/logs</code>

# %%
model.save_weights("./Saved_Models/Str_BigBird_Run2.h5")

# %%
u = model.evaluate(dataset[3][0], dataset[3][1])

# %%
u = model.predict(dataset[0][0])

# %%
u = u.argmax(-1)

# %%
u

# %%
dataset[0][1]

# %%
random_samples[0:5]
